# %% [markdown]
# <a href="https://colab.research.google.com/github/goya5858/OSERO/blob/main/A2C_cartpole_ray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -q -q -U 'ray[default]'

import ray

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import torch.multiprocessing as mp
import time

import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gym
import numpy as np
import matplotlib.pyplot as plt
from torch.nn import functional as F
import copy
# Out:
#      |████████████████████████████████| 49.4MB 168kB/s
#      |████████████████████████████████| 1.3MB 32.5MB/s
#      |████████████████████████████████| 81kB 8.5MB/s
#      |████████████████████████████████| 3.1MB 18.9MB/s
#      |████████████████████████████████| 81kB 9.0MB/s
#      |████████████████████████████████| 10.1MB 27.3MB/s
#      |████████████████████████████████| 1.0MB 28.2MB/s
#      |████████████████████████████████| 133kB 29.7MB/s
#      |████████████████████████████████| 71kB 6.2MB/s
#      |████████████████████████████████| 204kB 42.8MB/s
#      |████████████████████████████████| 143kB 36.8MB/s
#      |████████████████████████████████| 296kB 39.6MB/s
#      |████████████████████████████████| 92kB 8.8MB/s
#   Building wheel for gpustat (setup.py) ... done

# %% [markdown]
# # Agent

# %%
class Agent_Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1  = nn.Linear(4, 32)
        self.act1 = nn.ReLU()

        self.fc2  = nn.Linear(32, 32)
        self.act2 = nn.ReLU()

        self.pi_net = nn.Linear(32, 2)
        self.pi_act = nn.Softmax()

        self.V_net = nn.Linear(32,1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act1(x)

        x = self.fc2(x)
        x = self.act2(x)

        pi = self.pi_net(x)
        pi = self.pi_act(pi)

        V = self.V_net(x)
        return pi, V
    
    def get_weights(self):
        return {k: v.cpu() for k, v in self.state_dict().items()}

    def set_weights(self, weights):
        self.load_state_dict(weights)

    def get_gradients(self):
        grads = []
        for p in self.parameters():
            grad = None if p.grad is None else p.grad.data.cpu().numpy()
            grads.append(grad)
        return grads

    def set_gradients(self, gradients):
        for g, p in zip(gradients, self.parameters()):
            if g is not None:
                p.grad = torch.from_numpy(g)

# %%
from collections import namedtuple
Transition = namedtuple('Transition', ('state', 'action', 'reward', 'pi_prob', 'v_value'))

class Agent_Memory():
    def __init__(self):
        self.capacity = ADVANTAGE #Advantageを計算するために、Xstep分の履歴を保存する
        self.memory = []
        self.index = 0
    
    def put_memory(self, state, action, reward, pi_prob, v_value):
        '''transition = (self, state, action, reward, pi_prob, v_value)をメモリに保存する'''
        if len(self.memory) < self.capacity:
            self.memory.append(None)  # メモリが満タンでないときは足す
        self.memory[self.index] = Transition(state, action, reward, pi_prob, v_value)
        self.index = (self.index + 1) % self.capacity  # 保存するindexを1つずらす

    def get_Advantage(self, Last_V):
        transitions = self.memory
        #State, Action, Reward, State_Nextの各要素ごとにまとめ直しTensorに変換する
        BATCH = Transition(*zip(*transitions)) 
        State_BATCH   = torch.tensor( np.stack( BATCH.state ) ,dtype=torch.float)
        Action_BATCH  = torch.tensor( np.stack( BATCH.action ) ,dtype=torch.int64)
        Reward_BATCH  = torch.tensor( np.stack( BATCH.reward ) ,dtype=torch.float)
        Pi_prob_BATCH = torch.stack( BATCH.pi_prob )
        V_value_BATCH = torch.stack( BATCH.v_value )

        # Nstep分の割引報酬を計算し、Advantageを計算する
        Returns        = torch.zeros([Reward_BATCH.shape[0]+1]) 
        Returns[-1]  = Last_V
        for i in reversed(range(len(Reward_BATCH))):
            Returns[i] = Reward_BATCH[i]+GAMMA*Returns[i+1]
        Returns   = Returns[:-1].reshape(1,-1)
        Advantage = Returns.detach() - V_value_BATCH
        return Advantage.reshape(-1), Pi_prob_BATCH

# %%
# Master-Agent
# Worker-Agentが入手した勾配をまとめて同期的に受け取って、自身の重みを更新し、WorkerAgentに渡す
class MasterAgent():
    def __init__(self):
        self.Network = Agent_Network()
        self.optim   = optim.Adam(self.Network.parameters(), lr=LR)
        self.scheduler = optim.lr_scheduler.StepLR(optimizer=self.optim, step_size=LR_STEP, gamma=LR_GAMMA)
    
    def apply_gradients(self, *gradients):
        summed_gradients = [
            np.stack(gradient_zip).mean(axis=0) for gradient_zip in zip(*gradients)
        ]
        summed_gradients = summed_gradients[0]
        self.optim.zero_grad()
        self.Network.set_gradients(summed_gradients)
        nn.utils.clip_grad_norm_(self.Network.parameters(), CLIP)
        self.optim.step()
        self.scheduler.step()
        return self.Network.get_weights()

    def get_weights(self):
        return self.Network.get_weights()

# %%
# 実際にタスクをこなして、勾配を計算して出力する
# Masterより受け取った重みを自身に適用する
class WorkerAgent():
    def __init__(self):
        self.Network = Agent_Network()
        self.Memory  = Agent_Memory()
    
    def set_weights(self, weights):
        self.Network.set_weights(weights)

    def get_action(self, state, episode): 
        # ε-greedy法で徐々に最適行動のみを採用する
        #self.Network.eval()  # ネットワークを推論モードに切り替える
        pi_values, V_value = self.Network( torch.tensor( state, dtype=torch.float ) )
        m = Categorical(pi_values)

        epsilon = 0.5 * (1 / (episode + 1))
        if epsilon <= np.random.uniform(0, 1):
            action = m.sample()
        else:
            action = np.random.choice(2)   # 0,1の行動をランダムに返す
            action = torch.tensor( action )
        #log_prob = -1 * m.log_prob(action)
        pi_prob = m.probs[ action.to(torch.long) ]
        return action, pi_prob, V_value[0]

    def compute_gradients(self, Last_V):
        # Memoryから学習用のデータを取り出す
        Advantage, Pi_prob_BATCH = self.Memory.get_Advantage(Last_V)

        V_loss  = Advantage.pow(2).mean() #２乗平均をとる
        Log_prob_BATCH = torch.log( Pi_prob_BATCH )
        pi_gain = ( Log_prob_BATCH * Advantage.detach() ).mean()
        entropy  = -1*( Pi_prob_BATCH * Log_prob_BATCH ).mean()

        loss = 0.5*V_loss - pi_gain #- 0.01*entropy
        loss.backward()
        
        self.Memory.memory = []
        self.Memory.index = 0
        return self.Network.get_gradients()
    
    def memorize(self, state, action, reward, pi_prob, v_value):
        self.Memory.put_memory(state, action, reward, pi_prob, v_value)

# %% [markdown]
# # Task

# %%
#Task_model = gym.make('CartPole-v0')

# %% [markdown]
# # Worker-Task-Env

# %%
# Advantage_Step分タスクを行い、その都度計算された勾配を返す環境
# WorkerAgentとTaskをそれぞれ保持している

@ray.remote
class Work_on_Task:
    def __init__(self):
        self.Worker = WorkerAgent()
        self.Task   = gym.make('CartPole-v0')
        self.T      = 0 #経過時間
        self.done   = False
        self.state  = self.Task.reset()
    
    def step_Advantage(self, state, current_weights, episode):
        # Advantage_Step分、タスクを進めて　State, Action, Rewordを記録する
        self.Worker.set_weights(current_weights) # 最初にMasterからWorkerに重みをコピーする
        for advantage_step in range(ADVANTAGE): #Advantage分のStepsを1サイクルと考える    
            action, pi_prob, v_value       = self.Worker.get_action(state, episode)
            state_next, reword, done, info = self.Task.step(action.item()) #Action_tを場面に渡してState_t+1, Reword_tを受け取る

            if done: #倒れていたor終了した場合
                next_state = None
                if self.T < 195: #195ステップ以内なら失敗
                    reword = -1
                else: #195ステップ以上たってたら成功
                    reword = 1
            else: #各ステップで立ってたら報酬追加
                reword = 0

            # 結果の記録
            self.Worker.memorize(state, action, reword, pi_prob, v_value)
            state = state_next
            self.T += 1
            
            if done:# Advantageの途中で終わってたら抜ける
                break 
        return state, done, self.T
    
    def compute_gradients(self, state, episode):
        # Advantage_Step分の行動の記録から勾配を計算する
        if state is not None:
            _, _, Last_V  = self.Worker.get_action(state, episode)
        else:
            Last_V = torch.tensor(0)
        gradients = [self.Worker.compute_gradients(Last_V)]
        return gradients
    
    def steps_and_grad(self, current_weights, episode):
        # 上記の２つのメソッドを同時にこなす
        if not self.done:
            state = self.state
            state, done, t = self.step_Advantage(state, current_weights, episode)
            gradients      = self.compute_gradients(state, episode)
            self.state = state
            self.done   = done
        else:
            gradients = None
        return gradients, self.done, self.T
    
    def reset(self):
        self.state  = self.Task.reset()
        self.T = 0
        self.done   = False

# %% [markdown]
# # Training Environment

# %%
class Environment():
    def __init__(self):
        self.Master        = MasterAgent()
        self.Work_on_Tasks = [ Work_on_Task.remote() for _ in range(NUM_PROCESS) ]
    
    def run_one_episode(self, episode):
        # 倒れるか、200秒持ち堪え耐えるまでが１エピソード
        # 各episodeの最初にTaskをリセット        
        [worker.reset.remote() for worker in self.Work_on_Tasks]
        current_weights = self.Master.get_weights()
        while True:
            # Advantage_step分進めるのをひとまとまりとする
            A = [ worker.steps_and_grad.remote(current_weights, episode) for worker in self.Work_on_Tasks ]
            A = ray.get(A)
            gradients, done, ts = zip(*A)
            gradients = [grad for grad in gradients if grad is not None]
            current_weights    = self.Master.apply_gradients(*gradients)
            done = True if sum(done)==NUM_PROCESS else False
            t = np.mean(ts)
            if done: #全体のループを抜ける 
                [worker.reset.remote() for worker in self.Work_on_Tasks]
                break    
        return t, ts
    
    def train(self):
        TIMES = []
        times = 0
        episode = 0
        while True:
            times, Times = self.run_one_episode(episode)
            print('episode :', episode)
            print("mean_time :", times)
            print("times :", Times)
            print('='*10, "\n")
            episode += 1
            TIMES.append(times)

            if ( (len(TIMES) > 10) & (np.mean(TIMES[-10:]) >= 150) ) or (len(TIMES) > MAX_ITER):
                break
        return TIMES

# %%
NUM_PROCESS = 8
ADVANTAGE = 5

MAX_ITER = 1000
GAMMA = 0.99
CLIP = 0.005
LR = 0.0005 / NUM_PROCESS

LR_STEP  = 100
LR_GAMMA = 1

ray.init(ignore_reinit_error=True)
AAA = Environment()
TTT = AAA.train()

X = range(len(TTT))
plt.plot(X, TTT)
ray.shutdown()
# Out:
# 2021-06-13 13:49:01,302	INFO worker.py:737 -- Calling ray.init() again after it has already been called.
# 2021-06-13 13:49:02,217	WARNING worker.py:1114 -- WARNING: 12 PYTHON workers have been started on a node of the id: 02527c4279cff78c8ab7ba7c8e901255b0aae101a4b734c37434be6d and address: 172.28.0.2. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2021-06-13 13:49:03,905	WARNING worker.py:1114 -- WARNING: 14 PYTHON workers have been started on a node of the id: 02527c4279cff78c8ab7ba7c8e901255b0aae101a4b734c37434be6d and address: 172.28.0.2. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2021-06-13 13:49:06,699	WARNING worker.py:1114 -- WARNING: 16 PYTHON workers have been started on a node of the id: 02527c4279cff78c8ab7ba7c8e901255b0aae101a4b734c37434be6d and address: 172.28.0.2. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=493) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=493)   type=str,
# (pid=494) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=494)   type=str,
# (pid=530) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=530)   type=str,
# (pid=539) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=539)   type=str,
# (pid=580) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=580)   type=str,
# (pid=571) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=571)   type=str,
# (pid=623) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=623)   type=str,
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# (pid=611) /usr/local/lib/python3.7/dist-packages/ray/workers/default_worker.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# (pid=611)   type=str,
# episode : 0
# mean_time : 31.25
# times : (48, 15, 30, 48, 32, 46, 14, 17)
# ==========
#
# episode : 1
# mean_time : 19.75
# times : (16, 33, 18, 28, 10, 14, 27, 12)
# ==========
#
# episode : 2
# mean_time : 23.375
# times : (35, 16, 38, 15, 15, 22, 26, 20)
# ==========
#
# episode : 3
# mean_time : 18.125
# times : (34, 12, 13, 11, 16, 20, 13, 26)
# ==========
#
# episode : 4
# mean_time : 28.0
# times : (13, 12, 16, 37, 32, 10, 44, 60)
# ==========
#
# episode : 5
# mean_time : 31.0
# times : (43, 44, 21, 16, 27, 8, 27, 62)
# ==========
#
# episode : 6
# mean_time : 19.75
# times : (11, 21, 16, 13, 21, 14, 21, 41)
# ==========
#
# episode : 7
# mean_time : 16.75
# times : (14, 13, 11, 20, 29, 11, 17, 19)
# ==========
#
# episode : 8
# mean_time : 22.0
# times : (41, 29, 12, 20, 25, 13, 19, 17)
# ==========
#
# episode : 9
# mean_time : 21.875
# times : (29, 42, 23, 28, 10, 11, 10, 22)
# ==========
#
# episode : 10
# mean_time : 19.5
# times : (39, 16, 32, 12, 12, 15, 11, 19)
# ==========
#
# episode : 11
# mean_time : 28.125
# times : (34, 27, 56, 32, 26, 12, 21, 17)
# ==========
#
# episode : 12
# mean_time : 15.0
# times : (16, 17, 14, 14, 12, 17, 14, 16)
# ==========
#
# episode : 13
# mean_time : 18.875
# times : (16, 33, 27, 15, 16, 12, 17, 15)
# ==========
#
# episode : 14
# mean_time : 25.875
# times : (16, 14, 10, 24, 18, 68, 31, 26)
# ==========
#
# episode : 15
# mean_time : 20.625
# times : (14, 25, 17, 39, 15, 13, 20, 22)
# ==========
#
# episode : 16
# mean_time : 16.875
# times : (17, 19, 16, 13, 13, 19, 12, 26)
# ==========
#
# episode : 17
# mean_time : 22.25
# times : (21, 22, 13, 43, 21, 26, 14, 18)
# ==========
#
# episode : 18
# mean_time : 33.0
# times : (33, 37, 59, 34, 26, 16, 24, 35)
# ==========
#
# episode : 19
# mean_time : 17.0
# times : (18, 12, 10, 13, 35, 15, 15, 18)
# ==========
#
# episode : 20
# mean_time : 20.625
# times : (17, 23, 13, 12, 11, 18, 38, 33)
# ==========
#
# episode : 21
# mean_time : 36.875
# times : (15, 50, 41, 12, 9, 60, 52, 56)
# ==========
#
# episode : 22
# mean_time : 23.5
# times : (23, 12, 11, 25, 45, 31, 20, 21)
# ==========
#
# episode : 23
# mean_time : 20.125
# times : (18, 29, 14, 13, 35, 17, 25, 10)
# ==========
#
# episode : 24
# mean_time : 31.625
# times : (34, 24, 20, 17, 34, 47, 51, 26)
# ==========
#
# episode : 25
# mean_time : 30.625
# times : (38, 16, 26, 24, 16, 17, 12, 96)
# ==========
#
# episode : 26
# mean_time : 23.125
# times : (33, 33, 10, 18, 19, 34, 23, 15)
# ==========
#
# episode : 27
# mean_time : 21.125
# times : (19, 15, 18, 17, 16, 21, 40, 23)
# ==========
#
# episode : 28
# mean_time : 28.75
# times : (19, 10, 32, 27, 25, 30, 19, 68)
# ==========
#
# episode : 29
# mean_time : 25.5
# times : (21, 12, 14, 21, 28, 20, 45, 43)
# ==========
#
# episode : 30
# mean_time : 31.125
# times : (36, 25, 20, 97, 25, 9, 20, 17)
# ==========
#
# episode : 31
# mean_time : 20.875
# times : (17, 16, 28, 23, 24, 19, 28, 12)
# ==========
#
# episode : 32
# mean_time : 21.375
# times : (22, 16, 11, 15, 19, 20, 31, 37)
# ==========
#
# episode : 33
# mean_time : 20.625
# times : (28, 12, 9, 19, 17, 20, 42, 18)
# ==========
#
# episode : 34
# mean_time : 17.875
# times : (17, 14, 15, 12, 16, 31, 27, 11)
# ==========
#
# episode : 35
# mean_time : 27.25
# times : (37, 39, 16, 29, 37, 23, 18, 19)
# ==========
#
# episode : 36
# mean_time : 22.875
# times : (9, 18, 19, 15, 20, 27, 45, 30)
# ==========
#
# episode : 37
# mean_time : 21.75
# times : (20, 13, 14, 36, 12, 39, 10, 30)
# ==========
#
# episode : 38
# mean_time : 25.75
# times : (39, 14, 38, 37, 15, 16, 38, 9)
# ==========
#
# episode : 39
# mean_time : 25.75
# times : (17, 13, 24, 34, 25, 28, 14, 51)
# ==========
#
# episode : 40
# mean_time : 27.375
# times : (11, 32, 14, 16, 50, 19, 37, 40)
# ==========
#
# episode : 41
# mean_time : 25.125
# times : (46, 49, 22, 26, 12, 16, 14, 16)
# ==========
#
# episode : 42
# mean_time : 19.5
# times : (20, 17, 21, 15, 20, 32, 14, 17)
# ==========
#
# episode : 43
# mean_time : 29.25
# times : (17, 19, 26, 26, 42, 20, 63, 21)
# ==========
#
# episode : 44
# mean_time : 20.75
# times : (25, 14, 27, 11, 14, 36, 23, 16)
# ==========
#
# episode : 45
# mean_time : 23.125
# times : (26, 19, 14, 24, 12, 25, 47, 18)
# ==========
#
# episode : 46
# mean_time : 29.0
# times : (14, 25, 20, 14, 67, 43, 17, 32)
# ==========
#
# episode : 47
# mean_time : 23.375
# times : (17, 19, 17, 21, 23, 20, 40, 30)
# ==========
#
# episode : 48
# mean_time : 21.75
# times : (12, 47, 18, 20, 15, 24, 20, 18)
# ==========
#
# episode : 49
# mean_time : 23.5
# times : (29, 25, 11, 38, 20, 16, 23, 26)
# ==========
#
# episode : 50
# mean_time : 23.625
# times : (17, 22, 18, 25, 34, 29, 15, 29)
# ==========
#
# episode : 51
# mean_time : 26.75
# times : (11, 13, 15, 50, 16, 18, 57, 34)
# ==========
#
# episode : 52
# mean_time : 32.5
# times : (46, 62, 55, 12, 23, 25, 13, 24)
# ==========
#
# episode : 53
# mean_time : 26.75
# times : (28, 34, 13, 19, 23, 49, 26, 22)
# ==========
#
# episode : 54
# mean_time : 30.375
# times : (14, 39, 19, 35, 50, 15, 36, 35)
# ==========
#
# episode : 55
# mean_time : 21.75
# times : (16, 36, 26, 13, 29, 21, 18, 15)
# ==========
#
# episode : 56
# mean_time : 23.375
# times : (31, 27, 15, 24, 28, 15, 20, 27)
# ==========
#
# episode : 57
# mean_time : 21.125
# times : (14, 15, 13, 52, 10, 18, 18, 29)
# ==========
#
# episode : 58
# mean_time : 25.375
# times : (53, 26, 13, 17, 12, 25, 38, 19)
# ==========
#
# episode : 59
# mean_time : 24.875
# times : (26, 9, 18, 23, 35, 15, 23, 50)
# ==========
#
# episode : 60
# mean_time : 21.75
# times : (15, 16, 26, 24, 46, 13, 20, 14)
# ==========
#
# episode : 61
# mean_time : 22.375
# times : (24, 15, 15, 11, 55, 18, 24, 17)
# ==========
#
# episode : 62
# mean_time : 25.0
# times : (19, 11, 17, 41, 50, 29, 18, 15)
# ==========
#
# episode : 63
# mean_time : 25.25
# times : (21, 20, 16, 21, 12, 41, 50, 21)
# ==========
#
# episode : 64
# mean_time : 17.125
# times : (19, 14, 11, 15, 21, 22, 17, 18)
# ==========
#
# episode : 65
# mean_time : 17.0
# times : (21, 14, 17, 16, 12, 19, 18, 19)
# ==========
#
# episode : 66
# mean_time : 16.0
# times : (12, 10, 27, 9, 14, 12, 22, 22)
# ==========
#
# episode : 67
# mean_time : 25.0
# times : (26, 11, 24, 17, 60, 10, 12, 40)
# ==========
#
# episode : 68
# mean_time : 24.375
# times : (12, 27, 19, 55, 25, 12, 22, 23)
# ==========
#
# episode : 69
# mean_time : 19.875
# times : (22, 10, 17, 28, 12, 29, 29, 12)
# ==========
#
# episode : 70
# mean_time : 25.375
# times : (26, 11, 62, 16, 28, 13, 21, 26)
# ==========
#
# episode : 71
# mean_time : 27.5
# times : (26, 54, 19, 25, 22, 13, 28, 33)
# ==========
#
# episode : 72
# mean_time : 23.75
# times : (17, 37, 23, 20, 14, 37, 31, 11)
# ==========
#
# episode : 73
# mean_time : 19.5
# times : (18, 17, 32, 15, 11, 12, 24, 27)
# ==========
#
# episode : 74
# mean_time : 25.875
# times : (14, 17, 25, 19, 21, 38, 17, 56)
# ==========
#
# episode : 75
# mean_time : 26.0
# times : (21, 22, 39, 10, 43, 16, 15, 42)
# ==========
#
# episode : 76
# mean_time : 26.0
# times : (44, 14, 11, 13, 15, 19, 36, 56)
# ==========
#
# episode : 77
# mean_time : 17.75
# times : (21, 16, 11, 12, 12, 17, 27, 26)
# ==========
#
# episode : 78
# mean_time : 26.75
# times : (21, 32, 49, 10, 24, 18, 17, 43)
# ==========
#
# episode : 79
# mean_time : 26.375
# times : (11, 29, 16, 46, 54, 37, 10, 8)
# ==========
#
# episode : 80
# mean_time : 29.375
# times : (32, 27, 50, 27, 21, 15, 33, 30)
# ==========
#
# episode : 81
# mean_time : 23.375
# times : (15, 23, 17, 23, 18, 32, 24, 35)
# ==========
#
# episode : 82
# mean_time : 18.375
# times : (10, 14, 19, 31, 23, 9, 18, 23)
# ==========
#
# episode : 83
# mean_time : 22.5
# times : (14, 21, 47, 22, 19, 23, 23, 11)
# ==========
#
# episode : 84
# mean_time : 21.75
# times : (27, 20, 12, 32, 22, 24, 23, 14)
# ==========
#
# episode : 85
# mean_time : 20.125
# times : (18, 17, 8, 27, 16, 22, 32, 21)
# ==========
#
# episode : 86
# mean_time : 23.5
# times : (31, 39, 30, 12, 12, 15, 18, 31)
# ==========
#
# episode : 87
# mean_time : 23.0
# times : (17, 25, 34, 12, 15, 23, 42, 16)
# ==========
#
# episode : 88
# mean_time : 25.375
# times : (71, 13, 21, 15, 10, 24, 14, 35)
# ==========
#
# episode : 89
# mean_time : 24.375
# times : (23, 24, 25, 32, 33, 13, 16, 29)
# ==========
#
# episode : 90
# mean_time : 22.25
# times : (10, 33, 10, 15, 44, 24, 9, 33)
# ==========
#
# episode : 91
# mean_time : 19.25
# times : (20, 33, 12, 13, 15, 14, 12, 35)
# ==========
#
# episode : 92
# mean_time : 25.75
# times : (29, 12, 39, 41, 24, 14, 16, 31)
# ==========
#
# episode : 93
# mean_time : 19.25
# times : (13, 33, 12, 9, 12, 18, 17, 40)
# ==========
#
# episode : 94
# mean_time : 16.75
# times : (13, 15, 18, 10, 21, 18, 10, 29)
# ==========
#
# episode : 95
# mean_time : 30.375
# times : (27, 58, 19, 27, 36, 12, 17, 47)
# ==========
#
# episode : 96
# mean_time : 23.125
# times : (12, 15, 31, 15, 12, 28, 15, 57)
# ==========
#
# episode : 97
# mean_time : 23.25
# times : (9, 27, 11, 17, 38, 37, 22, 25)
# ==========
#
# episode : 98
# mean_time : 31.375
# times : (11, 27, 24, 23, 15, 47, 45, 59)
# ==========
#
# episode : 99
# mean_time : 19.375
# times : (31, 21, 17, 17, 13, 22, 13, 21)
# ==========
#
# episode : 100
# mean_time : 21.375
# times : (11, 22, 21, 56, 16, 8, 22, 15)
# ==========
#
# episode : 101
# mean_time : 22.375
# times : (26, 24, 13, 20, 35, 16, 14, 31)
# ==========
#
# episode : 102
# mean_time : 31.0
# times : (27, 21, 58, 16, 14, 14, 49, 49)
# ==========
#
# episode : 103
# mean_time : 17.625
# times : (20, 14, 17, 14, 10, 13, 14, 39)
# ==========
#
# episode : 104
# mean_time : 24.75
# times : (36, 41, 29, 18, 15, 11, 18, 30)
# ==========
#
# episode : 105
# mean_time : 17.125
# times : (16, 18, 15, 30, 10, 11, 18, 19)
# ==========
#
# episode : 106
# mean_time : 22.75
# times : (19, 24, 30, 48, 14, 22, 10, 15)
# ==========
#
# episode : 107
# mean_time : 24.0
# times : (17, 29, 19, 11, 29, 27, 43, 17)
# ==========
#
# episode : 108
# mean_time : 24.125
# times : (43, 22, 13, 29, 32, 26, 14, 14)
# ==========
#
# episode : 109
# mean_time : 23.25
# times : (19, 22, 28, 44, 11, 21, 10, 31)
# ==========
#
# episode : 110
# mean_time : 18.875
# times : (15, 16, 23, 33, 10, 20, 19, 15)
# ==========
#
# episode : 111
# mean_time : 22.75
# times : (18, 15, 27, 28, 29, 15, 32, 18)
# ==========
#
# episode : 112
# mean_time : 19.625
# times : (12, 15, 55, 13, 14, 11, 15, 22)
# ==========
#
# episode : 113
# mean_time : 34.875
# times : (53, 74, 28, 21, 21, 16, 23, 43)
# ==========
#
# episode : 114
# mean_time : 21.875
# times : (12, 27, 17, 11, 25, 52, 20, 11)
# ==========
#
# episode : 115
# mean_time : 32.375
# times : (24, 23, 41, 17, 52, 40, 31, 31)
# ==========
#
# episode : 116
# mean_time : 19.5
# times : (14, 20, 14, 19, 13, 27, 24, 25)
# ==========
#
# episode : 117
# mean_time : 22.25
# times : (12, 31, 15, 14, 14, 43, 23, 26)
# ==========
#
# episode : 118
# mean_time : 22.75
# times : (12, 19, 14, 38, 24, 10, 52, 13)
# ==========
#
# episode : 119
# mean_time : 18.125
# times : (15, 12, 13, 20, 32, 13, 14, 26)
# ==========
#
# episode : 120
# mean_time : 15.0
# times : (22, 8, 26, 15, 12, 15, 9, 13)
# ==========
#
# episode : 121
# mean_time : 30.25
# times : (18, 13, 13, 12, 52, 106, 16, 12)
# ==========
#
# episode : 122
# mean_time : 30.875
# times : (43, 17, 45, 28, 12, 25, 30, 47)
# ==========
#
# episode : 123
# mean_time : 23.25
# times : (16, 25, 40, 22, 10, 28, 26, 19)
# ==========
#
# episode : 124
# mean_time : 33.0
# times : (10, 30, 75, 32, 63, 15, 13, 26)
# ==========
#
# episode : 125
# mean_time : 23.0
# times : (9, 19, 15, 19, 33, 35, 16, 38)
# ==========
#
# episode : 126
# mean_time : 21.25
# times : (16, 35, 13, 24, 23, 11, 10, 38)
# ==========
#
# episode : 127
# mean_time : 20.125
# times : (9, 46, 25, 14, 13, 15, 15, 24)
# ==========
#
# episode : 128
# mean_time : 27.5
# times : (32, 57, 26, 11, 15, 45, 13, 21)
# ==========
#
# episode : 129
# mean_time : 26.75
# times : (65, 22, 18, 35, 24, 17, 10, 23)
# ==========
#
# episode : 130
# mean_time : 30.625
# times : (38, 48, 32, 34, 26, 18, 39, 10)
# ==========
#
# episode : 131
# mean_time : 26.375
# times : (20, 38, 17, 16, 21, 23, 42, 34)
# ==========
#
# episode : 132
# mean_time : 25.25
# times : (12, 48, 12, 17, 14, 21, 18, 60)
# ==========
#
# episode : 133
# mean_time : 29.0
# times : (54, 20, 27, 32, 23, 26, 31, 19)
# ==========
#
# episode : 134
# mean_time : 24.5
# times : (34, 12, 29, 30, 16, 43, 21, 11)
# ==========
#
# episode : 135
# mean_time : 31.75
# times : (48, 54, 16, 12, 11, 83, 13, 17)
# ==========
#
# episode : 136
# mean_time : 21.375
# times : (13, 15, 20, 24, 13, 23, 35, 28)
# ==========
#
# episode : 137
# mean_time : 29.125
# times : (24, 17, 15, 68, 28, 39, 19, 23)
# ==========
#
# episode : 138
# mean_time : 26.125
# times : (23, 31, 26, 12, 58, 14, 22, 23)
# ==========
#
# episode : 139
# mean_time : 27.125
# times : (66, 20, 39, 21, 12, 26, 16, 17)
# ==========
#
# episode : 140
# mean_time : 21.625
# times : (27, 19, 16, 12, 22, 32, 21, 24)
# ==========
#
# episode : 141
# mean_time : 37.25
# times : (36, 33, 31, 14, 17, 67, 86, 14)
# ==========
#
# episode : 142
# mean_time : 29.875
# times : (22, 11, 48, 30, 25, 47, 40, 16)
# ==========
#
# episode : 143
# mean_time : 27.375
# times : (24, 13, 27, 54, 23, 43, 15, 20)
# ==========
#
# episode : 144
# mean_time : 34.75
# times : (12, 29, 28, 41, 11, 54, 84, 19)
# ==========
#
# episode : 145
# mean_time : 20.75
# times : (39, 20, 16, 17, 17, 20, 15, 22)
# ==========
#
# episode : 146
# mean_time : 31.125
# times : (12, 37, 48, 35, 27, 23, 34, 33)
# ==========
#
# episode : 147
# mean_time : 33.375
# times : (31, 48, 28, 27, 20, 14, 61, 38)
# ==========
#
# episode : 148
# mean_time : 22.875
# times : (27, 23, 27, 10, 17, 29, 33, 17)
# ==========
#
# episode : 149
# mean_time : 28.125
# times : (15, 14, 61, 43, 34, 20, 13, 25)
# ==========
#
# episode : 150
# mean_time : 39.875
# times : (35, 32, 16, 40, 44, 96, 33, 23)
# ==========
#
# episode : 151
# mean_time : 21.0
# times : (12, 17, 29, 16, 28, 18, 25, 23)
# ==========
#
# episode : 152
# mean_time : 27.875
# times : (49, 23, 21, 48, 21, 13, 19, 29)
# ==========
#
# episode : 153
# mean_time : 26.625
# times : (18, 17, 15, 13, 69, 20, 43, 18)
# ==========
#
# episode : 154
# mean_time : 30.25
# times : (60, 20, 11, 25, 25, 60, 26, 15)
# ==========
#
# episode : 155
# mean_time : 18.125
# times : (29, 17, 11, 21, 28, 20, 10, 9)
# ==========
#
# episode : 156
# mean_time : 21.25
# times : (17, 10, 22, 12, 16, 48, 33, 12)
# ==========
#
# episode : 157
# mean_time : 19.75
# times : (15, 22, 22, 18, 25, 18, 13, 25)
# ==========
#
# episode : 158
# mean_time : 23.125
# times : (58, 11, 12, 13, 36, 30, 14, 11)
# ==========
#
# episode : 159
# mean_time : 33.0
# times : (61, 32, 30, 18, 30, 44, 32, 17)
# ==========
#
# episode : 160
# mean_time : 23.0
# times : (35, 12, 16, 15, 57, 13, 20, 16)
# ==========
#
# episode : 161
# mean_time : 24.25
# times : (15, 21, 13, 32, 26, 24, 29, 34)
# ==========
#
# episode : 162
# mean_time : 21.625
# times : (14, 23, 27, 14, 21, 31, 22, 21)
# ==========
#
# episode : 163
# mean_time : 27.125
# times : (16, 27, 18, 21, 45, 43, 28, 19)
# ==========
#
# episode : 164
# mean_time : 28.375
# times : (11, 15, 25, 16, 44, 51, 32, 33)
# ==========
#
# episode : 165
# mean_time : 23.375
# times : (13, 10, 12, 24, 46, 12, 32, 38)
# ==========
#
# episode : 166
# mean_time : 24.0
# times : (35, 24, 22, 18, 22, 31, 26, 14)
# ==========
#
# episode : 167
# mean_time : 26.0
# times : (35, 32, 9, 18, 33, 13, 29, 39)
# ==========
#
# episode : 168
# mean_time : 22.375
# times : (18, 10, 20, 27, 20, 16, 23, 45)
# ==========
#
# episode : 169
# mean_time : 23.75
# times : (38, 33, 11, 23, 10, 13, 15, 47)
# ==========
#
# episode : 170
# mean_time : 18.625
# times : (30, 19, 14, 27, 19, 13, 14, 13)
# ==========
#
# episode : 171
# mean_time : 21.875
# times : (22, 24, 19, 17, 28, 20, 11, 34)
# ==========
#
# episode : 172
# mean_time : 38.625
# times : (48, 69, 24, 44, 68, 19, 16, 21)
# ==========
#
# episode : 173
# mean_time : 28.25
# times : (25, 19, 41, 40, 13, 17, 55, 16)
# ==========
#
# episode : 174
# mean_time : 19.625
# times : (13, 13, 33, 10, 15, 15, 34, 24)
# ==========
#
# episode : 175
# mean_time : 28.875
# times : (18, 17, 18, 24, 32, 91, 11, 20)
# ==========
#
# episode : 176
# mean_time : 31.5
# times : (50, 19, 21, 26, 72, 22, 27, 15)
# ==========
#
# episode : 177
# mean_time : 24.125
# times : (13, 18, 14, 23, 60, 11, 13, 41)
# ==========
#
# episode : 178
# mean_time : 30.625
# times : (60, 30, 75, 12, 14, 18, 22, 14)
# ==========
#
# episode : 179
# mean_time : 20.375
# times : (23, 14, 27, 12, 32, 11, 30, 14)
# ==========
#
# episode : 180
# mean_time : 21.5
# times : (15, 13, 19, 30, 15, 21, 12, 47)
# ==========
#
# episode : 181
# mean_time : 35.25
# times : (19, 13, 52, 10, 13, 32, 61, 82)
# ==========
#
# episode : 182
# mean_time : 29.125
# times : (27, 53, 11, 51, 14, 23, 29, 25)
# ==========
#
# episode : 183
# mean_time : 22.5
# times : (23, 10, 12, 29, 38, 16, 16, 36)
# ==========
#
# episode : 184
# mean_time : 20.75
# times : (16, 32, 17, 16, 22, 13, 18, 32)
# ==========
#
# episode : 185
# mean_time : 26.75
# times : (31, 25, 33, 78, 10, 12, 9, 16)
# ==========
#
# episode : 186
# mean_time : 22.0
# times : (12, 29, 25, 24, 18, 21, 33, 14)
# ==========
#
# episode : 187
# mean_time : 23.125
# times : (24, 35, 14, 29, 17, 23, 31, 12)
# ==========
#
# episode : 188
# mean_time : 20.25
# times : (21, 15, 21, 23, 13, 21, 12, 36)
# ==========
#
# episode : 189
# mean_time : 25.375
# times : (25, 15, 33, 12, 33, 28, 14, 43)
# ==========
#
# episode : 190
# mean_time : 23.125
# times : (10, 10, 22, 15, 12, 35, 34, 47)
# ==========
#
# episode : 191
# mean_time : 26.25
# times : (13, 14, 11, 38, 60, 15, 38, 21)
# ==========
#
# episode : 192
# mean_time : 27.0
# times : (39, 22, 26, 38, 16, 32, 20, 23)
# ==========
#
# episode : 193
# mean_time : 28.625
# times : (17, 14, 19, 29, 16, 58, 41, 35)
# ==========
#
# episode : 194
# mean_time : 30.5
# times : (78, 14, 59, 12, 14, 27, 19, 21)
# ==========
#
# episode : 195
# mean_time : 26.125
# times : (28, 17, 15, 16, 18, 20, 68, 27)
# ==========
#
# episode : 196
# mean_time : 24.5
# times : (26, 38, 19, 18, 45, 12, 20, 18)
# ==========
#
# episode : 197
# mean_time : 29.375
# times : (39, 14, 11, 32, 40, 19, 43, 37)
# ==========
#
# episode : 198
# mean_time : 31.875
# times : (34, 37, 24, 22, 70, 32, 26, 10)
# ==========
#
# episode : 199
# mean_time : 21.375
# times : (13, 52, 14, 15, 15, 18, 28, 16)
# ==========
#
# episode : 200
# mean_time : 24.75
# times : (23, 44, 32, 30, 24, 19, 15, 11)
# ==========
#
# episode : 201
# mean_time : 28.75
# times : (60, 15, 23, 18, 23, 27, 52, 12)
# ==========
#
# episode : 202
# mean_time : 25.75
# times : (24, 18, 13, 19, 29, 25, 58, 20)
# ==========
#
# episode : 203
# mean_time : 31.125
# times : (45, 15, 36, 15, 42, 15, 54, 27)
# ==========
#
# episode : 204
# mean_time : 33.0
# times : (33, 33, 95, 27, 15, 16, 27, 18)
# ==========
#
# episode : 205
# mean_time : 32.625
# times : (63, 43, 23, 13, 25, 22, 53, 19)
# ==========
#
# episode : 206
# mean_time : 36.0
# times : (30, 33, 36, 76, 14, 26, 32, 41)
# ==========
#
# episode : 207
# mean_time : 44.875
# times : (67, 11, 42, 33, 54, 46, 64, 42)
# ==========
#
# episode : 208
# mean_time : 29.375
# times : (51, 30, 30, 42, 32, 16, 16, 18)
# ==========
#
# episode : 209
# mean_time : 32.625
# times : (16, 32, 21, 52, 70, 21, 29, 20)
# ==========
#
# episode : 210
# mean_time : 29.25
# times : (34, 29, 24, 36, 18, 51, 17, 25)
# ==========
#
# episode : 211
# mean_time : 19.125
# times : (22, 17, 20, 27, 20, 12, 24, 11)
# ==========
#
# episode : 212
# mean_time : 32.125
# times : (23, 40, 34, 54, 17, 35, 44, 10)
# ==========
#
# episode : 213
# mean_time : 37.625
# times : (31, 42, 42, 84, 14, 17, 25, 46)
# ==========
#
# episode : 214
# mean_time : 32.125
# times : (60, 12, 35, 24, 17, 34, 55, 20)
# ==========
#
# episode : 215
# mean_time : 29.25
# times : (11, 21, 40, 19, 28, 75, 15, 25)
# ==========
#
# episode : 216
# mean_time : 35.375
# times : (13, 35, 42, 88, 20, 23, 27, 35)
# ==========
#
# episode : 217
# mean_time : 35.875
# times : (29, 73, 40, 11, 47, 33, 16, 38)
# ==========
#
# episode : 218
# mean_time : 35.125
# times : (27, 18, 11, 46, 26, 35, 40, 78)
# ==========
#
# episode : 219
# mean_time : 25.375
# times : (24, 10, 12, 16, 52, 34, 22, 33)
# ==========
#
# episode : 220
# mean_time : 22.5
# times : (10, 21, 36, 21, 9, 19, 15, 49)
# ==========
#
# episode : 221
# mean_time : 28.5
# times : (34, 20, 52, 24, 42, 15, 20, 21)
# ==========
#
# episode : 222
# mean_time : 37.5
# times : (46, 80, 38, 42, 24, 19, 11, 40)
# ==========
#
# episode : 223
# mean_time : 27.0
# times : (46, 22, 23, 12, 36, 13, 46, 18)
# ==========
#
# episode : 224
# mean_time : 36.25
# times : (17, 32, 44, 26, 43, 62, 41, 25)
# ==========
#
# episode : 225
# mean_time : 23.875
# times : (28, 30, 23, 12, 27, 26, 22, 23)
# ==========
#
# episode : 226
# mean_time : 35.375
# times : (41, 18, 34, 35, 92, 12, 33, 18)
# ==========
#
# episode : 227
# mean_time : 25.5
# times : (28, 36, 26, 17, 23, 27, 24, 23)
# ==========
#
# episode : 228
# mean_time : 29.5
# times : (20, 18, 20, 30, 47, 34, 50, 17)
# ==========
#
# episode : 229
# mean_time : 31.875
# times : (23, 25, 43, 11, 45, 20, 30, 58)
# ==========
#
# episode : 230
# mean_time : 33.125
# times : (21, 61, 18, 13, 35, 43, 28, 46)
# ==========
#
# episode : 231
# mean_time : 16.625
# times : (11, 19, 15, 28, 17, 18, 15, 10)
# ==========
#
# episode : 232
# mean_time : 27.25
# times : (30, 9, 15, 18, 26, 56, 38, 26)
# ==========
#
# episode : 233
# mean_time : 29.125
# times : (14, 19, 33, 21, 17, 40, 37, 52)
# ==========
#
# episode : 234
# mean_time : 53.25
# times : (31, 42, 100, 28, 24, 140, 34, 27)
# ==========
#
# episode : 235
# mean_time : 24.125
# times : (18, 28, 16, 22, 24, 40, 27, 18)
# ==========
#
# episode : 236
# mean_time : 38.0
# times : (103, 16, 10, 35, 19, 22, 24, 75)
# ==========
#
# episode : 237
# mean_time : 33.75
# times : (16, 23, 13, 12, 36, 100, 30, 40)
# ==========
#
# episode : 238
# mean_time : 30.0
# times : (39, 41, 24, 27, 20, 37, 29, 23)
# ==========
#
# episode : 239
# mean_time : 28.125
# times : (23, 27, 57, 22, 42, 17, 20, 17)
# ==========
#
# episode : 240
# mean_time : 40.0
# times : (59, 26, 21, 16, 65, 21, 41, 71)
# ==========
#
# episode : 241
# mean_time : 37.25
# times : (16, 72, 46, 38, 13, 31, 60, 22)
# ==========
#
# episode : 242
# mean_time : 49.5
# times : (35, 26, 66, 25, 69, 36, 124, 15)
# ==========
#
# episode : 243
# mean_time : 36.875
# times : (27, 54, 24, 13, 27, 84, 35, 31)
# ==========
#
# episode : 244
# mean_time : 35.875
# times : (18, 12, 23, 110, 40, 39, 13, 32)
# ==========
#
# episode : 245
# mean_time : 38.0
# times : (36, 59, 27, 23, 89, 20, 26, 24)
# ==========
#
# episode : 246
# mean_time : 41.625
# times : (19, 64, 36, 47, 18, 29, 81, 39)
# ==========
#
# episode : 247
# mean_time : 29.375
# times : (39, 13, 14, 34, 47, 16, 37, 35)
# ==========
#
# episode : 248
# mean_time : 54.625
# times : (57, 25, 101, 35, 68, 42, 41, 68)
# ==========
#
# episode : 249
# mean_time : 50.875
# times : (46, 111, 20, 66, 43, 17, 46, 58)
# ==========
#
# episode : 250
# mean_time : 44.5
# times : (21, 22, 60, 42, 36, 54, 36, 85)
# ==========
#
# episode : 251
# mean_time : 39.75
# times : (31, 40, 22, 42, 50, 26, 95, 12)
# ==========
#
# episode : 252
# mean_time : 49.25
# times : (41, 44, 20, 41, 100, 36, 36, 76)
# ==========
#
# episode : 253
# mean_time : 48.25
# times : (43, 65, 22, 19, 110, 57, 35, 35)
# ==========
#
# episode : 254
# mean_time : 53.875
# times : (61, 53, 71, 21, 42, 114, 38, 31)
# ==========
#
# episode : 255
# mean_time : 30.0
# times : (37, 16, 15, 32, 31, 21, 27, 61)
# ==========
#
# episode : 256
# mean_time : 57.125
# times : (35, 128, 38, 41, 92, 23, 37, 63)
# ==========
#
# episode : 257
# mean_time : 58.0
# times : (48, 25, 53, 60, 91, 88, 43, 56)
# ==========
#
# episode : 258
# mean_time : 47.875
# times : (50, 25, 44, 46, 41, 67, 72, 38)
# ==========
#
# episode : 259
# mean_time : 53.125
# times : (61, 54, 28, 84, 32, 45, 97, 24)
# ==========
#
# episode : 260
# mean_time : 45.25
# times : (18, 52, 28, 60, 50, 69, 33, 52)
# ==========
#
# episode : 261
# mean_time : 57.5
# times : (63, 36, 110, 61, 62, 43, 67, 18)
# ==========
#
# episode : 262
# mean_time : 45.375
# times : (34, 38, 57, 69, 50, 32, 26, 57)
# ==========
#
# episode : 263
# mean_time : 54.875
# times : (59, 30, 30, 73, 70, 58, 89, 30)
# ==========
#
# episode : 264
# mean_time : 52.125
# times : (38, 35, 51, 39, 85, 30, 70, 69)
# ==========
#
# episode : 265
# mean_time : 47.75
# times : (31, 40, 45, 59, 41, 63, 54, 49)
# ==========
#
# episode : 266
# mean_time : 41.375
# times : (43, 25, 40, 59, 22, 43, 62, 37)
# ==========
#
# episode : 267
# mean_time : 42.0
# times : (34, 30, 48, 27, 88, 47, 22, 40)
# ==========
#
# episode : 268
# mean_time : 46.5
# times : (49, 94, 44, 25, 45, 50, 29, 36)
# ==========
#
# episode : 269
# mean_time : 53.875
# times : (78, 36, 57, 52, 53, 60, 55, 40)
# ==========
#
# episode : 270
# mean_time : 56.875
# times : (34, 41, 41, 62, 41, 41, 50, 145)
# ==========
#
# episode : 271
# mean_time : 49.125
# times : (38, 40, 41, 44, 49, 66, 67, 48)
# ==========
#
# episode : 272
# mean_time : 31.75
# times : (40, 33, 20, 21, 32, 24, 27, 57)
# ==========
#
# episode : 273
# mean_time : 55.5
# times : (55, 30, 113, 35, 49, 64, 48, 50)
# ==========
#
# episode : 274
# mean_time : 57.875
# times : (22, 83, 41, 29, 84, 78, 87, 39)
# ==========
#
# episode : 275
# mean_time : 51.625
# times : (40, 56, 72, 62, 38, 50, 51, 44)
# ==========
#
# episode : 276
# mean_time : 49.125
# times : (24, 123, 23, 54, 26, 57, 42, 44)
# ==========
#
# episode : 277
# mean_time : 55.5
# times : (48, 73, 51, 38, 77, 39, 61, 57)
# ==========
#
# episode : 278
# mean_time : 69.125
# times : (93, 58, 19, 164, 42, 56, 62, 59)
# ==========
#
# episode : 279
# mean_time : 42.375
# times : (92, 19, 26, 45, 35, 56, 39, 27)
# ==========
#
# episode : 280
# mean_time : 46.875
# times : (56, 35, 34, 33, 55, 38, 48, 76)
# ==========
#
# episode : 281
# mean_time : 44.0
# times : (20, 38, 42, 42, 31, 47, 41, 91)
# ==========
#
# episode : 282
# mean_time : 41.375
# times : (47, 26, 44, 36, 29, 44, 61, 44)
# ==========
#
# episode : 283
# mean_time : 48.5
# times : (46, 41, 61, 31, 65, 70, 51, 23)
# ==========
#
# episode : 284
# mean_time : 82.375
# times : (81, 42, 55, 104, 200, 80, 50, 47)
# ==========
#
# episode : 285
# mean_time : 47.375
# times : (30, 47, 39, 54, 67, 44, 48, 50)
# ==========
#
# episode : 286
# mean_time : 69.375
# times : (53, 39, 78, 59, 36, 48, 147, 95)
# ==========
#
# episode : 287
# mean_time : 42.375
# times : (53, 29, 51, 46, 33, 38, 27, 62)
# ==========
#
# episode : 288
# mean_time : 51.375
# times : (66, 34, 42, 33, 121, 40, 25, 50)
# ==========
#
# episode : 289
# mean_time : 38.25
# times : (24, 36, 38, 34, 61, 62, 20, 31)
# ==========
#
# episode : 290
# mean_time : 72.875
# times : (122, 52, 25, 33, 149, 35, 42, 125)
# ==========
#
# episode : 291
# mean_time : 46.5
# times : (31, 59, 61, 50, 48, 47, 29, 47)
# ==========
#
# episode : 292
# mean_time : 53.0
# times : (96, 50, 58, 67, 42, 46, 46, 19)
# ==========
#
# episode : 293
# mean_time : 49.25
# times : (40, 53, 63, 22, 48, 31, 57, 80)
# ==========
#
# episode : 294
# mean_time : 52.125
# times : (69, 33, 39, 81, 43, 38, 38, 76)
# ==========
#
# episode : 295
# mean_time : 53.0
# times : (67, 41, 38, 36, 45, 57, 61, 79)
# ==========
#
# episode : 296
# mean_time : 48.5
# times : (77, 44, 54, 60, 29, 49, 42, 33)
# ==========
#
# episode : 297
# mean_time : 51.0
# times : (44, 46, 47, 39, 110, 56, 39, 27)
# ==========
#
# episode : 298
# mean_time : 51.625
# times : (49, 73, 48, 59, 48, 35, 51, 50)
# ==========
#
# episode : 299
# mean_time : 67.5
# times : (43, 75, 41, 92, 82, 45, 94, 68)
# ==========
#
# episode : 300
# mean_time : 51.25
# times : (39, 57, 37, 29, 65, 49, 63, 71)
# ==========
#
# episode : 301
# mean_time : 54.5
# times : (58, 61, 44, 59, 64, 80, 38, 32)
# ==========
#
# episode : 302
# mean_time : 68.75
# times : (72, 56, 73, 67, 55, 52, 49, 126)
# ==========
#
# episode : 303
# mean_time : 62.0
# times : (65, 107, 57, 61, 34, 61, 64, 47)
# ==========
#
# episode : 304
# mean_time : 60.375
# times : (86, 75, 52, 46, 73, 75, 36, 40)
# ==========
#
# episode : 305
# mean_time : 64.25
# times : (54, 49, 72, 61, 75, 75, 65, 63)
# ==========
#
# episode : 306
# mean_time : 66.25
# times : (64, 67, 81, 63, 69, 50, 56, 80)
# ==========
#
# episode : 307
# mean_time : 66.0
# times : (54, 80, 38, 87, 77, 85, 48, 59)
# ==========
#
# episode : 308
# mean_time : 83.375
# times : (57, 38, 60, 170, 44, 138, 69, 91)
# ==========
#
# episode : 309
# mean_time : 76.375
# times : (99, 69, 70, 84, 47, 129, 51, 62)
# ==========
#
# episode : 310
# mean_time : 61.375
# times : (53, 38, 63, 70, 64, 71, 59, 73)
# ==========
#
# episode : 311
# mean_time : 71.875
# times : (47, 97, 67, 69, 42, 62, 105, 86)
# ==========
#
# episode : 312
# mean_time : 79.625
# times : (54, 84, 63, 64, 78, 117, 138, 39)
# ==========
#
# episode : 313
# mean_time : 65.625
# times : (41, 64, 42, 58, 117, 65, 43, 95)
# ==========
#
# episode : 314
# mean_time : 71.875
# times : (119, 57, 58, 57, 74, 62, 81, 67)
# ==========
#
# episode : 315
# mean_time : 78.875
# times : (78, 91, 109, 63, 74, 63, 53, 100)
# ==========
#
# episode : 316
# mean_time : 78.625
# times : (46, 56, 80, 48, 51, 73, 200, 75)
# ==========
#
# episode : 317
# mean_time : 69.5
# times : (97, 103, 43, 85, 58, 62, 46, 62)
# ==========
#
# episode : 318
# mean_time : 75.875
# times : (80, 96, 92, 73, 41, 91, 89, 45)
# ==========
#
# episode : 319
# mean_time : 74.875
# times : (74, 83, 52, 145, 44, 95, 54, 52)
# ==========
#
# episode : 320
# mean_time : 59.375
# times : (71, 34, 74, 49, 67, 68, 47, 65)
# ==========
#
# episode : 321
# mean_time : 92.5
# times : (54, 112, 72, 76, 101, 68, 120, 137)
# ==========
#
# episode : 322
# mean_time : 79.875
# times : (66, 96, 74, 97, 101, 61, 52, 92)
# ==========
#
# episode : 323
# mean_time : 70.375
# times : (52, 63, 58, 61, 64, 56, 83, 126)
# ==========
#
# episode : 324
# mean_time : 67.5
# times : (98, 86, 45, 85, 42, 59, 43, 82)
# ==========
#
# episode : 325
# mean_time : 71.5
# times : (59, 94, 83, 87, 64, 45, 53, 87)
# ==========
#
# episode : 326
# mean_time : 75.375
# times : (62, 78, 44, 66, 83, 61, 46, 163)
# ==========
#
# episode : 327
# mean_time : 64.25
# times : (57, 39, 57, 66, 76, 67, 102, 50)
# ==========
#
# episode : 328
# mean_time : 82.875
# times : (194, 40, 102, 64, 56, 82, 56, 69)
# ==========
#
# episode : 329
# mean_time : 81.375
# times : (68, 164, 171, 40, 54, 44, 62, 48)
# ==========
#
# episode : 330
# mean_time : 73.875
# times : (82, 96, 82, 65, 56, 113, 58, 39)
# ==========
#
# episode : 331
# mean_time : 67.25
# times : (54, 57, 98, 65, 38, 72, 61, 93)
# ==========
#
# episode : 332
# mean_time : 62.25
# times : (54, 48, 57, 79, 65, 87, 67, 41)
# ==========
#
# episode : 333
# mean_time : 97.25
# times : (79, 84, 87, 88, 143, 89, 114, 94)
# ==========
#
# episode : 334
# mean_time : 77.875
# times : (51, 113, 76, 83, 120, 59, 49, 72)
# ==========
#
# episode : 335
# mean_time : 90.75
# times : (64, 46, 73, 90, 55, 191, 91, 116)
# ==========
#
# episode : 336
# mean_time : 73.25
# times : (104, 72, 50, 80, 101, 46, 57, 76)
# ==========
#
# episode : 337
# mean_time : 69.25
# times : (89, 79, 78, 46, 52, 83, 63, 64)
# ==========
#
# episode : 338
# mean_time : 82.125
# times : (137, 85, 89, 63, 75, 87, 67, 54)
# ==========
#
# episode : 339
# mean_time : 62.0
# times : (79, 55, 68, 45, 105, 50, 45, 49)
# ==========
#
# episode : 340
# mean_time : 83.75
# times : (61, 65, 153, 75, 89, 74, 87, 66)
# ==========
#
# episode : 341
# mean_time : 79.625
# times : (54, 113, 85, 59, 129, 50, 73, 74)
# ==========
#
# episode : 342
# mean_time : 70.75
# times : (68, 79, 51, 41, 66, 60, 83, 118)
# ==========
#
# episode : 343
# mean_time : 76.625
# times : (76, 38, 88, 147, 67, 85, 60, 52)
# ==========
#
# episode : 344
# mean_time : 93.75
# times : (63, 103, 84, 67, 121, 50, 122, 140)
# ==========
#
# episode : 345
# mean_time : 79.25
# times : (93, 54, 44, 78, 157, 85, 71, 52)
# ==========
#
# episode : 346
# mean_time : 70.125
# times : (59, 78, 65, 83, 61, 61, 94, 60)
# ==========
#
# episode : 347
# mean_time : 72.5
# times : (109, 95, 56, 78, 54, 57, 53, 78)
# ==========
#
# episode : 348
# mean_time : 81.625
# times : (133, 66, 57, 49, 53, 93, 122, 80)
# ==========
#
# episode : 349
# mean_time : 68.125
# times : (55, 79, 103, 70, 60, 73, 49, 56)
# ==========
#
# episode : 350
# mean_time : 73.5
# times : (77, 61, 55, 109, 77, 78, 64, 67)
# ==========
#
# episode : 351
# mean_time : 78.25
# times : (83, 75, 65, 140, 69, 49, 74, 71)
# ==========
#
# episode : 352
# mean_time : 80.625
# times : (81, 68, 133, 59, 71, 74, 85, 74)
# ==========
#
# episode : 353
# mean_time : 93.625
# times : (59, 105, 119, 90, 54, 118, 103, 101)
# ==========
#
# episode : 354
# mean_time : 72.125
# times : (59, 63, 51, 135, 84, 66, 58, 61)
# ==========
#
# episode : 355
# mean_time : 87.125
# times : (125, 69, 112, 86, 52, 105, 68, 80)
# ==========
#
# episode : 356
# mean_time : 85.5
# times : (87, 75, 69, 60, 102, 93, 128, 70)
# ==========
#
# episode : 357
# mean_time : 81.875
# times : (60, 53, 62, 75, 142, 66, 62, 135)
# ==========
#
# episode : 358
# mean_time : 94.25
# times : (59, 84, 167, 68, 65, 112, 120, 79)
# ==========
#
# episode : 359
# mean_time : 88.125
# times : (93, 157, 56, 57, 110, 73, 115, 44)
# ==========
#
# episode : 360
# mean_time : 71.75
# times : (67, 55, 56, 105, 53, 89, 60, 89)
# ==========
#
# episode : 361
# mean_time : 71.75
# times : (71, 66, 74, 80, 58, 56, 101, 68)
# ==========
#
# episode : 362
# mean_time : 96.625
# times : (157, 112, 70, 76, 57, 48, 109, 144)
# ==========
#
# episode : 363
# mean_time : 79.625
# times : (58, 80, 84, 79, 115, 56, 69, 96)
# ==========
#
# episode : 364
# mean_time : 77.75
# times : (64, 133, 57, 86, 57, 75, 71, 79)
# ==========
#
# episode : 365
# mean_time : 86.75
# times : (100, 104, 53, 67, 48, 159, 97, 66)
# ==========
#
# episode : 366
# mean_time : 85.75
# times : (137, 59, 111, 61, 65, 89, 53, 111)
# ==========
#
# episode : 367
# mean_time : 79.0
# times : (49, 130, 62, 80, 69, 55, 100, 87)
# ==========
#
# episode : 368
# mean_time : 86.25
# times : (179, 82, 66, 135, 59, 38, 50, 81)
# ==========
#
# episode : 369
# mean_time : 65.25
# times : (62, 64, 72, 66, 52, 54, 90, 62)
# ==========
#
# episode : 370
# mean_time : 90.5
# times : (84, 82, 200, 58, 73, 94, 70, 63)
# ==========
#
# episode : 371
# mean_time : 98.5
# times : (60, 83, 137, 94, 72, 89, 55, 198)
# ==========
#
# episode : 372
# mean_time : 88.125
# times : (65, 139, 44, 94, 169, 65, 61, 68)
# ==========
#
# episode : 373
# mean_time : 82.375
# times : (73, 86, 58, 85, 101, 81, 78, 97)
# ==========
#
# episode : 374
# mean_time : 78.125
# times : (92, 99, 59, 54, 131, 59, 73, 58)
# ==========
#
# episode : 375
# mean_time : 89.75
# times : (44, 177, 51, 66, 73, 75, 116, 116)
# ==========
#
# episode : 376
# mean_time : 89.375
# times : (71, 65, 71, 106, 48, 91, 86, 177)
# ==========
#
# episode : 377
# mean_time : 81.375
# times : (110, 44, 113, 114, 58, 62, 45, 105)
# ==========
#
# episode : 378
# mean_time : 75.5
# times : (96, 67, 98, 67, 72, 91, 62, 51)
# ==========
#
# episode : 379
# mean_time : 73.75
# times : (119, 59, 77, 86, 71, 45, 55, 78)
# ==========
#
# episode : 380
# mean_time : 82.875
# times : (56, 83, 65, 80, 60, 95, 105, 119)
# ==========
#
# episode : 381
# mean_time : 89.0
# times : (54, 87, 87, 77, 59, 101, 162, 85)
# ==========
#
# episode : 382
# mean_time : 85.0
# times : (112, 83, 124, 91, 61, 57, 87, 65)
# ==========
#
# episode : 383
# mean_time : 95.875
# times : (171, 62, 156, 95, 72, 62, 69, 80)
# ==========
#
# episode : 384
# mean_time : 80.25
# times : (74, 108, 74, 52, 74, 81, 119, 60)
# ==========
#
# episode : 385
# mean_time : 87.75
# times : (62, 69, 69, 136, 63, 87, 67, 149)
# ==========
#
# episode : 386
# mean_time : 62.75
# times : (58, 59, 86, 57, 54, 85, 49, 54)
# ==========
#
# episode : 387
# mean_time : 68.125
# times : (54, 58, 86, 105, 69, 48, 63, 62)
# ==========
#
# episode : 388
# mean_time : 83.875
# times : (62, 85, 142, 72, 59, 84, 54, 113)
# ==========
#
# episode : 389
# mean_time : 94.375
# times : (80, 84, 68, 75, 181, 119, 78, 70)
# ==========
#
# episode : 390
# mean_time : 79.5
# times : (66, 90, 89, 84, 66, 85, 79, 77)
# ==========
#
# episode : 391
# mean_time : 72.625
# times : (59, 126, 61, 63, 72, 55, 76, 69)
# ==========
#
# episode : 392
# mean_time : 76.125
# times : (81, 58, 61, 83, 101, 68, 87, 70)
# ==========
#
# episode : 393
# mean_time : 82.375
# times : (100, 67, 79, 78, 58, 52, 86, 139)
# ==========
#
# episode : 394
# mean_time : 72.0
# times : (68, 70, 68, 51, 88, 67, 81, 83)
# ==========
#
# episode : 395
# mean_time : 73.75
# times : (155, 71, 63, 63, 59, 54, 65, 60)
# ==========
#
# episode : 396
# mean_time : 93.0
# times : (67, 61, 145, 73, 61, 52, 191, 94)
# ==========
#
# episode : 397
# mean_time : 90.875
# times : (108, 94, 117, 79, 54, 82, 132, 61)
# ==========
#
# episode : 398
# mean_time : 69.5
# times : (63, 53, 57, 68, 68, 59, 121, 67)
# ==========
#
# episode : 399
# mean_time : 94.875
# times : (178, 65, 55, 117, 82, 76, 122, 64)
# ==========
#
# episode : 400
# mean_time : 96.375
# times : (113, 71, 150, 166, 44, 70, 96, 61)
# ==========
#
# episode : 401
# mean_time : 79.25
# times : (69, 65, 57, 75, 149, 61, 59, 99)
# ==========
#
# episode : 402
# mean_time : 89.75
# times : (70, 125, 149, 75, 58, 86, 91, 64)
# ==========
#
# episode : 403
# mean_time : 76.25
# times : (93, 70, 144, 58, 43, 49, 77, 76)
# ==========
#
# episode : 404
# mean_time : 97.5
# times : (55, 109, 153, 57, 63, 152, 72, 119)
# ==========
#
# episode : 405
# mean_time : 90.25
# times : (75, 102, 64, 107, 75, 119, 91, 89)
# ==========
#
# episode : 406
# mean_time : 66.5
# times : (49, 75, 65, 49, 52, 49, 86, 107)
# ==========
#
# episode : 407
# mean_time : 63.375
# times : (61, 71, 71, 52, 45, 51, 55, 101)
# ==========
#
# episode : 408
# mean_time : 92.875
# times : (90, 77, 65, 136, 67, 79, 97, 132)
# ==========
#
# episode : 409
# mean_time : 78.25
# times : (56, 46, 69, 143, 64, 120, 61, 67)
# ==========
#
# episode : 410
# mean_time : 121.5
# times : (80, 68, 186, 90, 200, 165, 116, 67)
# ==========
#
# episode : 411
# mean_time : 101.625
# times : (57, 79, 84, 154, 75, 155, 107, 102)
# ==========
#
# episode : 412
# mean_time : 76.5
# times : (90, 67, 57, 72, 125, 59, 85, 57)
# ==========
#
# episode : 413
# mean_time : 88.875
# times : (81, 68, 118, 75, 144, 57, 99, 69)
# ==========
#
# episode : 414
# mean_time : 78.5
# times : (71, 55, 61, 92, 130, 70, 81, 68)
# ==========
#
# episode : 415
# mean_time : 83.875
# times : (86, 65, 72, 79, 64, 85, 160, 60)
# ==========
#
# episode : 416
# mean_time : 83.125
# times : (68, 115, 96, 80, 66, 102, 64, 74)
# ==========
#
# episode : 417
# mean_time : 92.375
# times : (117, 84, 71, 67, 69, 87, 110, 134)
# ==========
#
# episode : 418
# mean_time : 82.125
# times : (135, 53, 59, 67, 79, 88, 52, 124)
# ==========
#
# episode : 419
# mean_time : 92.25
# times : (137, 53, 86, 94, 90, 112, 104, 62)
# ==========
#
# episode : 420
# mean_time : 82.75
# times : (76, 135, 57, 74, 83, 69, 108, 60)
# ==========
#
# episode : 421
# mean_time : 76.75
# times : (50, 47, 54, 60, 63, 173, 94, 73)
# ==========
#
# episode : 422
# mean_time : 83.25
# times : (63, 90, 97, 63, 75, 67, 84, 127)
# ==========
#
# episode : 423
# mean_time : 88.375
# times : (81, 84, 68, 127, 76, 73, 96, 102)
# ==========
#
# episode : 424
# mean_time : 81.625
# times : (85, 82, 73, 98, 74, 67, 89, 85)
# ==========
#
# episode : 425
# mean_time : 86.375
# times : (90, 94, 93, 84, 82, 86, 52, 110)
# ==========
#
# episode : 426
# mean_time : 79.375
# times : (93, 63, 121, 65, 94, 59, 85, 55)
# ==========
#
# episode : 427
# mean_time : 96.75
# times : (77, 103, 90, 153, 77, 94, 83, 97)
# ==========
#
# episode : 428
# mean_time : 79.75
# times : (81, 85, 87, 51, 81, 126, 64, 63)
# ==========
#
# episode : 429
# mean_time : 90.625
# times : (83, 63, 59, 75, 85, 77, 200, 83)
# ==========
#
# episode : 430
# mean_time : 103.375
# times : (63, 161, 87, 113, 86, 139, 72, 106)
# ==========
#
# episode : 431
# mean_time : 93.75
# times : (111, 93, 72, 83, 65, 163, 92, 71)
# ==========
#
# episode : 432
# mean_time : 82.5
# times : (66, 64, 181, 68, 73, 72, 75, 61)
# ==========
#
# episode : 433
# mean_time : 69.25
# times : (61, 71, 73, 56, 57, 68, 96, 72)
# ==========
#
# episode : 434
# mean_time : 81.0
# times : (69, 72, 59, 114, 63, 73, 138, 60)
# ==========
#
# episode : 435
# mean_time : 97.375
# times : (98, 133, 106, 87, 97, 102, 79, 77)
# ==========
#
# episode : 436
# mean_time : 69.5
# times : (58, 88, 65, 71, 70, 79, 59, 66)
# ==========
#
# episode : 437
# mean_time : 92.0
# times : (63, 71, 157, 68, 92, 119, 84, 82)
# ==========
#
# episode : 438
# mean_time : 104.75
# times : (65, 68, 75, 136, 122, 167, 124, 81)
# ==========
#
# episode : 439
# mean_time : 96.375
# times : (60, 140, 102, 95, 74, 77, 156, 67)
# ==========
#
# episode : 440
# mean_time : 96.0
# times : (58, 151, 84, 100, 120, 78, 82, 95)
# ==========
#
# episode : 441
# mean_time : 100.625
# times : (77, 102, 120, 68, 200, 89, 83, 66)
# ==========
#
# episode : 442
# mean_time : 80.375
# times : (126, 57, 63, 109, 61, 53, 70, 104)
# ==========
#
# episode : 443
# mean_time : 106.125
# times : (73, 114, 81, 119, 105, 200, 55, 102)
# ==========
#
# episode : 444
# mean_time : 98.25
# times : (98, 71, 113, 117, 110, 112, 55, 110)
# ==========
#
# episode : 445
# mean_time : 88.5
# times : (90, 83, 73, 125, 65, 114, 93, 65)
# ==========
#
# episode : 446
# mean_time : 89.5
# times : (66, 58, 88, 84, 90, 101, 137, 92)
# ==========
#
# episode : 447
# mean_time : 95.875
# times : (93, 68, 142, 89, 112, 82, 71, 110)
# ==========
#
# episode : 448
# mean_time : 99.625
# times : (115, 114, 84, 130, 103, 96, 90, 65)
# ==========
#
# episode : 449
# mean_time : 90.875
# times : (73, 99, 82, 91, 121, 86, 79, 96)
# ==========
#
# episode : 450
# mean_time : 111.0
# times : (200, 59, 124, 86, 122, 100, 120, 77)
# ==========
#
# episode : 451
# mean_time : 92.625
# times : (74, 110, 54, 98, 92, 139, 81, 93)
# ==========
#
# episode : 452
# mean_time : 80.875
# times : (64, 103, 95, 73, 68, 94, 79, 71)
# ==========
#
# episode : 453
# mean_time : 92.25
# times : (121, 62, 143, 72, 108, 72, 99, 61)
# ==========
#
# episode : 454
# mean_time : 96.125
# times : (75, 100, 67, 144, 81, 96, 106, 100)
# ==========
#
# episode : 455
# mean_time : 104.5
# times : (91, 60, 96, 92, 90, 141, 184, 82)
# ==========
#
# episode : 456
# mean_time : 85.0
# times : (101, 76, 80, 84, 104, 68, 89, 78)
# ==========
#
# episode : 457
# mean_time : 132.375
# times : (130, 104, 200, 200, 155, 108, 95, 67)
# ==========
#
# episode : 458
# mean_time : 114.75
# times : (197, 99, 64, 118, 107, 107, 102, 124)
# ==========
#
# episode : 459
# mean_time : 93.0
# times : (112, 70, 65, 107, 126, 98, 74, 92)
# ==========
#
# episode : 460
# mean_time : 78.875
# times : (80, 68, 79, 70, 90, 105, 74, 65)
# ==========
#
# episode : 461
# mean_time : 99.625
# times : (135, 96, 100, 65, 136, 95, 87, 83)
# ==========
#
# episode : 462
# mean_time : 107.0
# times : (157, 100, 114, 134, 83, 91, 100, 77)
# ==========
#
# episode : 463
# mean_time : 100.875
# times : (68, 102, 123, 82, 76, 108, 92, 156)
# ==========
#
# episode : 464
# mean_time : 111.25
# times : (87, 68, 146, 104, 120, 200, 84, 81)
# ==========
#
# episode : 465
# mean_time : 95.125
# times : (94, 73, 100, 98, 137, 122, 74, 63)
# ==========
#
# episode : 466
# mean_time : 122.75
# times : (108, 196, 106, 128, 108, 104, 114, 118)
# ==========
#
# episode : 467
# mean_time : 112.125
# times : (72, 110, 122, 99, 105, 58, 191, 140)
# ==========
#
# episode : 468
# mean_time : 102.375
# times : (111, 99, 83, 91, 117, 104, 126, 88)
# ==========
#
# episode : 469
# mean_time : 123.0
# times : (125, 88, 140, 137, 106, 110, 78, 200)
# ==========
#
# episode : 470
# mean_time : 94.5
# times : (60, 146, 86, 68, 95, 90, 81, 130)
# ==========
#
# episode : 471
# mean_time : 101.125
# times : (98, 74, 77, 90, 64, 101, 167, 138)
# ==========
#
# episode : 472
# mean_time : 117.125
# times : (74, 66, 144, 182, 118, 89, 200, 64)
# ==========
#
# episode : 473
# mean_time : 118.25
# times : (85, 195, 88, 113, 83, 82, 198, 102)
# ==========
#
# episode : 474
# mean_time : 121.75
# times : (200, 134, 88, 104, 114, 62, 72, 200)
# ==========
#
# episode : 475
# mean_time : 99.125
# times : (78, 89, 81, 197, 84, 94, 96, 74)
# ==========
#
# episode : 476
# mean_time : 114.75
# times : (95, 200, 80, 200, 96, 92, 69, 86)
# ==========
#
# episode : 477
# mean_time : 139.125
# times : (179, 134, 124, 138, 132, 200, 115, 91)
# ==========
#
# episode : 478
# mean_time : 108.625
# times : (164, 134, 73, 86, 72, 90, 98, 152)
# ==========
#
# episode : 479
# mean_time : 121.875
# times : (110, 70, 83, 141, 81, 200, 90, 200)
# ==========
#
# episode : 480
# mean_time : 111.375
# times : (94, 98, 117, 129, 152, 99, 108, 94)
# ==========
#
# episode : 481
# mean_time : 116.125
# times : (136, 200, 105, 94, 83, 74, 84, 153)
# ==========
#
# episode : 482
# mean_time : 105.625
# times : (200, 73, 100, 120, 70, 120, 90, 72)
# ==========
#
# episode : 483
# mean_time : 134.0
# times : (200, 72, 121, 101, 200, 90, 200, 88)
# ==========
#
# episode : 484
# mean_time : 125.0
# times : (200, 97, 68, 86, 124, 109, 200, 116)
# ==========
#
# episode : 485
# mean_time : 75.625
# times : (70, 68, 93, 60, 100, 62, 76, 76)
# ==========
#
# episode : 486
# mean_time : 111.625
# times : (132, 94, 94, 92, 119, 143, 73, 146)
# ==========
#
# episode : 487
# mean_time : 116.75
# times : (81, 200, 108, 66, 105, 107, 67, 200)
# ==========
#
# episode : 488
# mean_time : 141.75
# times : (92, 112, 191, 200, 138, 115, 86, 200)
# ==========
#
# episode : 489
# mean_time : 115.0
# times : (66, 200, 135, 82, 109, 143, 88, 97)
# ==========
#
# episode : 490
# mean_time : 128.125
# times : (102, 116, 170, 200, 90, 71, 190, 86)
# ==========
#
# episode : 491
# mean_time : 125.5
# times : (200, 116, 80, 76, 104, 200, 100, 128)
# ==========
#
# episode : 492
# mean_time : 132.5
# times : (175, 90, 167, 104, 200, 161, 68, 95)
# ==========
#
# episode : 493
# mean_time : 125.25
# times : (94, 189, 197, 76, 169, 80, 64, 133)
# ==========
#
# episode : 494
# mean_time : 125.625
# times : (76, 106, 153, 106, 74, 144, 200, 146)
# ==========
#
# episode : 495
# mean_time : 122.5
# times : (97, 200, 92, 79, 85, 200, 116, 111)
# ==========
#
# episode : 496
# mean_time : 95.375
# times : (72, 172, 68, 80, 84, 78, 106, 103)
# ==========
#
# episode : 497
# mean_time : 127.0
# times : (92, 80, 94, 200, 81, 69, 200, 200)
# ==========
#
# episode : 498
# mean_time : 113.75
# times : (160, 108, 70, 159, 130, 72, 83, 128)
# ==========
#
# episode : 499
# mean_time : 105.0
# times : (104, 200, 103, 80, 74, 143, 66, 70)
# ==========
#
# episode : 500
# mean_time : 128.0
# times : (108, 200, 94, 68, 174, 80, 200, 100)
# ==========
#
# episode : 501
# mean_time : 118.75
# times : (200, 89, 169, 117, 96, 75, 116, 88)
# ==========
#
# episode : 502
# mean_time : 133.0
# times : (170, 139, 92, 168, 95, 155, 158, 87)
# ==========
#
# episode : 503
# mean_time : 123.0
# times : (81, 115, 100, 154, 200, 124, 87, 123)
# ==========
#
# episode : 504
# mean_time : 105.625
# times : (200, 114, 82, 82, 84, 116, 71, 96)
# ==========
#
# episode : 505
# mean_time : 158.125
# times : (200, 200, 190, 140, 200, 160, 94, 81)
# ==========
#
# episode : 506
# mean_time : 151.75
# times : (200, 123, 200, 72, 92, 200, 127, 200)
# ==========
#
# episode : 507
# mean_time : 160.25
# times : (200, 200, 99, 132, 200, 144, 107, 200)
# ==========
#
# episode : 508
# mean_time : 125.25
# times : (109, 140, 111, 62, 74, 200, 106, 200)
# ==========
#
# episode : 509
# mean_time : 133.125
# times : (111, 95, 76, 200, 200, 93, 90, 200)
# ==========
#
# episode : 510
# mean_time : 134.25
# ...
# ==========
#
# episode : 619
# mean_time : 76.375
# times : (54, 44, 200, 128, 44, 48, 56, 37)
# ==========
#
# episode : 620
# mean_time : 50.375
# times : (47, 58, 49, 67, 43, 50, 32, 57)
# ==========
#
# episode : 621
# mean_time : 64.75
# times : (53, 35, 200, 39, 42, 55, 43, 51)
# ==========
#
# episode : 622
# mean_time : 91.875
# times : (88, 40, 87, 52, 39, 157, 200, 72)
# ==========
#
# episode : 623
# mean_time : 49.25
# times : (43, 47, 34, 44, 63, 71, 47, 45)
# ==========
#
# episode : 624
# mean_time : 55.5
# times : (43, 35, 64, 90, 66, 51, 62, 33)
# ==========
#
# episode : 625
# mean_time : 66.625
# times : (40, 45, 45, 35, 55, 197, 45, 71)
# ==========
#
# episode : 626
# mean_time : 65.625
# times : (67, 177, 39, 46, 65, 38, 61, 32)
# ==========
#
# episode : 627
# mean_time : 81.375
# times : (55, 54, 55, 200, 32, 39, 173, 43)
# ==========
#
# episode : 628
# mean_time : 96.75
# times : (38, 68, 200, 44, 200, 105, 57, 62)
# ==========
#
# episode : 629
# mean_time : 85.0
# times : (68, 58, 37, 200, 39, 45, 33, 200)
# ==========
#
# episode : 630
# mean_time : 42.375
# times : (34, 54, 35, 58, 47, 37, 35, 39)
# ==========
#
# episode : 631
# mean_time : 98.5
# times : (51, 48, 200, 121, 37, 32, 99, 200)
# ==========
#
# episode : 632
# mean_time : 90.875
# times : (54, 48, 86, 200, 200, 63, 45, 31)
# ==========
#
# episode : 633
# mean_time : 53.125
# times : (52, 64, 41, 82, 61, 37, 49, 39)
# ==========
#
# episode : 634
# mean_time : 45.75
# times : (40, 44, 34, 54, 43, 39, 39, 73)
# ==========
#
# episode : 635
# mean_time : 67.375
# times : (61, 45, 89, 36, 91, 36, 140, 41)
# ==========
#
# episode : 636
# mean_time : 45.75
# times : (59, 40, 57, 41, 46, 35, 35, 53)
# ==========
#
# episode : 637
# mean_time : 84.75
# times : (51, 52, 45, 125, 200, 87, 63, 55)
# ==========
#
# episode : 638
# mean_time : 53.875
# times : (60, 49, 48, 42, 61, 65, 73, 33)
# ==========
#
# episode : 639
# mean_time : 59.625
# times : (32, 200, 39, 41, 52, 42, 37, 34)
# ==========
#
# episode : 640
# mean_time : 59.0
# times : (40, 200, 34, 35, 30, 44, 34, 55)
# ==========
#
# episode : 641
# mean_time : 116.75
# times : (43, 51, 42, 200, 200, 35, 163, 200)
# ==========
#
# episode : 642
# mean_time : 49.625
# times : (49, 57, 39, 45, 45, 53, 52, 57)
# ==========
#
# episode : 643
# mean_time : 66.0
# times : (47, 41, 30, 77, 50, 39, 44, 200)
# ==========
#
# episode : 644
# mean_time : 77.75
# times : (40, 153, 200, 39, 43, 48, 36, 63)
# ==========
#
# episode : 645
# mean_time : 104.0
# times : (37, 200, 62, 35, 200, 57, 41, 200)
# ==========
#
# episode : 646
# mean_time : 104.5
# times : (200, 43, 200, 39, 47, 60, 47, 200)
# ==========
#
# episode : 647
# mean_time : 72.0
# times : (72, 55, 87, 35, 33, 200, 42, 52)
# ==========
#
# episode : 648
# mean_time : 46.625
# times : (40, 71, 45, 47, 41, 35, 46, 48)
# ==========
#
# episode : 649
# mean_time : 50.25
# times : (43, 32, 51, 43, 50, 33, 93, 57)
# ==========
#
# episode : 650
# mean_time : 70.25
# times : (109, 34, 95, 76, 95, 54, 49, 50)
# ==========
#
# episode : 651
# mean_time : 89.25
# times : (200, 105, 81, 64, 120, 41, 67, 36)
# ==========
#
# episode : 652
# mean_time : 64.375
# times : (47, 52, 48, 48, 45, 43, 32, 200)
# ==========
#
# episode : 653
# mean_time : 70.0
# times : (200, 67, 46, 31, 82, 52, 50, 32)
# ==========
#
# episode : 654
# mean_time : 72.875
# times : (33, 85, 200, 41, 58, 62, 66, 38)
# ==========
#
# episode : 655
# mean_time : 81.375
# times : (36, 40, 36, 31, 168, 200, 51, 89)
# ==========
#
# episode : 656
# mean_time : 76.625
# times : (50, 102, 49, 200, 41, 45, 81, 45)
# ==========
#
# episode : 657
# mean_time : 55.0
# times : (52, 47, 50, 60, 98, 40, 41, 52)
# ==========
#
# episode : 658
# mean_time : 85.375
# times : (80, 36, 200, 37, 53, 39, 200, 38)
# ==========
#
# episode : 659
# mean_time : 83.0
# times : (200, 47, 30, 33, 66, 44, 44, 200)
# ==========
#
# episode : 660
# mean_time : 66.0
# times : (40, 45, 33, 39, 39, 72, 60, 200)
# ==========
#
# episode : 661
# mean_time : 51.625
# times : (28, 34, 59, 72, 34, 75, 75, 36)
# ==========
#
# episode : 662
# mean_time : 55.5
# times : (55, 79, 37, 53, 60, 34, 39, 87)
# ==========
#
# episode : 663
# mean_time : 45.625
# times : (43, 51, 45, 37, 58, 55, 42, 34)
# ==========
#
# episode : 664
# mean_time : 55.375
# times : (51, 54, 39, 29, 37, 39, 158, 36)
# ==========
#
# episode : 665
# mean_time : 58.875
# times : (66, 33, 36, 65, 82, 47, 30, 112)
# ==========
#
# episode : 666
# mean_time : 81.625
# times : (200, 43, 39, 60, 36, 38, 200, 37)
# ==========
#
# episode : 667
# mean_time : 93.125
# times : (200, 73, 33, 73, 52, 200, 43, 71)
# ==========
#
# episode : 668
# mean_time : 104.875
# times : (200, 200, 51, 51, 42, 60, 200, 35)
# ==========
#
# episode : 669
# mean_time : 43.5
# times : (58, 49, 53, 32, 33, 56, 32, 35)
# ==========
#
# episode : 670
# mean_time : 59.5
# times : (52, 34, 31, 50, 34, 39, 200, 36)
# ==========
#
# episode : 671
# mean_time : 70.125
# times : (43, 200, 37, 61, 89, 43, 55, 33)
# ==========
#
# episode : 672
# mean_time : 46.125
# times : (51, 42, 53, 42, 51, 47, 47, 36)
# ==========
#
# episode : 673
# mean_time : 56.5
# times : (168, 39, 37, 43, 43, 43, 42, 37)
# ==========
#
# episode : 674
# mean_time : 49.25
# times : (54, 37, 45, 95, 40, 39, 47, 37)
# ==========
#
# episode : 675
# mean_time : 95.5
# times : (200, 63, 54, 80, 90, 200, 36, 41)
# ==========
#
# episode : 676
# mean_time : 70.0
# times : (60, 123, 30, 51, 60, 88, 89, 59)
# ==========
#
# episode : 677
# mean_time : 65.0
# times : (52, 33, 48, 45, 200, 52, 45, 45)
# ==========
#
# episode : 678
# mean_time : 63.75
# times : (200, 39, 55, 38, 51, 39, 35, 53)
# ==========
#
# episode : 679
# mean_time : 111.75
# times : (34, 31, 155, 37, 200, 200, 37, 200)
# ==========
#
# episode : 680
# mean_time : 75.75
# times : (61, 38, 67, 55, 46, 99, 40, 200)
# ==========
#
# episode : 681
# mean_time : 61.375
# times : (62, 40, 40, 43, 63, 122, 65, 56)
# ==========
#
# episode : 682
# mean_time : 87.375
# times : (47, 69, 50, 51, 43, 200, 200, 39)
# ==========
#
# episode : 683
# mean_time : 62.25
# times : (37, 41, 49, 47, 43, 200, 34, 47)
# ==========
#
# episode : 684
# mean_time : 63.5
# times : (58, 65, 47, 165, 41, 34, 45, 53)
# ==========
#
# episode : 685
# mean_time : 67.125
# times : (63, 59, 173, 56, 46, 36, 52, 52)
# ==========
#
# episode : 686
# mean_time : 69.75
# times : (45, 35, 50, 53, 64, 70, 41, 200)
# ==========
#
# episode : 687
# mean_time : 47.125
# times : (37, 43, 60, 40, 37, 37, 48, 75)
# ==========
#
# episode : 688
# mean_time : 91.125
# times : (200, 51, 42, 49, 68, 63, 56, 200)
# ==========
#
# episode : 689
# mean_time : 66.875
# times : (200, 61, 52, 42, 59, 34, 45, 42)
# ==========
#
# episode : 690
# mean_time : 53.0
# times : (47, 47, 51, 57, 59, 65, 52, 46)
# ==========
#
# episode : 691
# mean_time : 63.0
# times : (42, 55, 41, 42, 39, 42, 43, 200)
# ==========
#
# episode : 692
# mean_time : 73.5
# times : (200, 50, 48, 42, 40, 37, 54, 117)
# ==========
#
# episode : 693
# mean_time : 60.625
# times : (65, 35, 42, 133, 42, 58, 56, 54)
# ==========
#
# episode : 694
# mean_time : 92.375
# times : (57, 75, 200, 200, 54, 58, 56, 39)
# ==========
#
# episode : 695
# mean_time : 108.0
# times : (47, 69, 41, 200, 55, 200, 200, 52)
# ==========
#
# episode : 696
# mean_time : 64.375
# times : (64, 59, 49, 37, 156, 60, 35, 55)
# ==========
#
# episode : 697
# mean_time : 67.75
# times : (39, 200, 50, 46, 41, 61, 61, 44)
# ==========
#
# episode : 698
# mean_time : 76.375
# times : (52, 99, 72, 200, 38, 51, 50, 49)
# ==========
#
# episode : 699
# mean_time : 65.125
# times : (174, 65, 39, 40, 51, 50, 38, 64)
# ==========
#
# episode : 700
# mean_time : 97.75
# times : (38, 38, 200, 143, 67, 200, 42, 54)
# ==========
#
# episode : 701
# mean_time : 82.375
# times : (52, 40, 200, 56, 46, 39, 53, 173)
# ==========
#
# episode : 702
# mean_time : 73.5
# times : (52, 51, 200, 57, 63, 46, 73, 46)
# ==========
#
# episode : 703
# mean_time : 49.5
# times : (52, 41, 64, 53, 50, 42, 42, 52)
# ==========
#
# episode : 704
# mean_time : 88.75
# times : (188, 64, 162, 95, 67, 46, 43, 45)
# ==========
#
# episode : 705
# mean_time : 58.125
# times : (42, 70, 42, 56, 59, 87, 59, 50)
# ==========
#
# episode : 706
# mean_time : 69.75
# times : (71, 150, 50, 48, 43, 76, 54, 66)
# ==========
#
# episode : 707
# mean_time : 53.75
# times : (50, 56, 76, 53, 44, 69, 42, 40)
# ==========
#
# episode : 708
# mean_time : 69.25
# times : (46, 67, 62, 68, 50, 90, 97, 74)
# ==========
#
# episode : 709
# mean_time : 55.25
# times : (60, 42, 57, 50, 60, 54, 66, 53)
# ==========
#
# episode : 710
# mean_time : 79.5
# times : (47, 54, 46, 45, 66, 66, 112, 200)
# ==========
#
# episode : 711
# mean_time : 79.25
# times : (63, 59, 53, 50, 200, 84, 67, 58)
# ==========
#
# episode : 712
# mean_time : 98.125
# times : (52, 67, 192, 70, 51, 73, 80, 200)
# ==========
#
# episode : 713
# mean_time : 85.625
# times : (48, 100, 84, 107, 54, 200, 50, 42)
# ==========
#
# episode : 714
# mean_time : 77.125
# times : (79, 75, 50, 54, 68, 78, 161, 52)
# ==========
#
# episode : 715
# mean_time : 77.125
# times : (48, 77, 79, 138, 61, 98, 60, 56)
# ==========
#
# episode : 716
# mean_time : 83.75
# times : (74, 55, 175, 77, 67, 79, 71, 72)
# ==========
#
# episode : 717
# mean_time : 108.25
# times : (77, 54, 109, 153, 179, 123, 90, 81)
# ==========
#
# episode : 718
# mean_time : 82.0
# times : (54, 60, 67, 200, 53, 70, 54, 98)
# ==========
#
# episode : 719
# mean_time : 92.375
# times : (56, 145, 65, 82, 55, 65, 197, 74)
# ==========
#
# episode : 720
# mean_time : 124.875
# times : (200, 81, 200, 128, 61, 105, 70, 154)
# ==========
#
# episode : 721
# mean_time : 104.25
# times : (81, 121, 97, 90, 66, 151, 71, 157)
# ==========
#
# episode : 722
# mean_time : 110.625
# times : (89, 86, 200, 77, 143, 65, 87, 138)
# ==========
#
# episode : 723
# mean_time : 81.875
# times : (69, 62, 57, 93, 76, 63, 77, 158)
# ==========
#
# episode : 724
# mean_time : 131.875
# times : (149, 140, 200, 72, 88, 157, 186, 63)
# ==========
#
# episode : 725
# mean_time : 122.625
# times : (83, 179, 127, 118, 71, 109, 200, 94)
# ==========
#
# episode : 726
# mean_time : 127.875
# times : (87, 98, 95, 93, 200, 158, 200, 92)
# ==========
#
# episode : 727
# mean_time : 159.75
# times : (200, 87, 83, 200, 200, 200, 200, 108)
# ==========
#
# episode : 728
# mean_time : 162.75
# times : (94, 200, 200, 200, 200, 200, 103, 105)
# ==========
#
# episode : 729
# mean_time : 130.625
# times : (113, 161, 86, 115, 200, 88, 200, 82)
# ==========
#
# episode : 730
# mean_time : 153.0
# times : (189, 97, 200, 200, 103, 200, 92, 143)
# ==========
#
# episode : 731
# mean_time : 103.0
# times : (74, 104, 107, 87, 156, 76, 127, 93)
# ==========
#
# episode : 732
# mean_time : 137.875
# times : (200, 106, 124, 170, 121, 200, 73, 109)
# ==========
#
# episode : 733
# mean_time : 161.625
# times : (200, 171, 103, 84, 200, 200, 200, 135)
# ==========
#
# episode : 734
# mean_time : 124.75
# times : (200, 112, 104, 85, 100, 75, 122, 200)
# ==========
#
# episode : 735
# mean_time : 100.5
# times : (82, 92, 106, 146, 103, 97, 83, 95)
# ==========
#
# episode : 736
# mean_time : 101.5
# times : (90, 71, 93, 69, 200, 79, 126, 84)
# ==========
#
# episode : 737
# mean_time : 100.625
# times : (104, 59, 80, 200, 76, 105, 80, 101)
# ==========
#
# episode : 738
# mean_time : 74.625
# times : (54, 86, 62, 89, 81, 83, 77, 65)
# ==========
#
# episode : 739
# mean_time : 82.375
# times : (73, 99, 57, 73, 127, 85, 62, 83)
# ==========
#
# episode : 740
# mean_time : 95.75
# times : (119, 104, 106, 78, 81, 86, 75, 117)
# ==========
#
# episode : 741
# mean_time : 83.75
# times : (79, 83, 81, 88, 66, 72, 119, 82)
# ==========
#
# episode : 742
# mean_time : 84.625
# times : (55, 119, 65, 65, 103, 64, 125, 81)
# ==========
#
# episode : 743
# mean_time : 72.375
# times : (79, 57, 60, 104, 95, 64, 56, 64)
# ==========
#
# episode : 744
# mean_time : 76.375
# times : (77, 105, 101, 73, 72, 69, 58, 56)
# ==========
#
# episode : 745
# mean_time : 79.875
# times : (56, 105, 55, 113, 81, 103, 57, 69)
# ==========
#
# episode : 746
# mean_time : 77.875
# times : (72, 105, 63, 58, 101, 82, 58, 84)
# ==========
#
# episode : 747
# mean_time : 67.125
# times : (57, 50, 54, 69, 113, 67, 68, 59)
# ==========
#
# episode : 748
# mean_time : 73.25
# times : (96, 54, 65, 75, 59, 67, 91, 79)
# ==========
#
# episode : 749
# mean_time : 62.625
# times : (50, 70, 77, 67, 63, 63, 48, 63)
# ==========
#
# episode : 750
# mean_time : 76.0
# times : (55, 93, 67, 116, 109, 59, 54, 55)
# ==========
#
# episode : 751
# mean_time : 73.875
# times : (101, 57, 53, 105, 70, 65, 51, 89)
# ==========
#
# episode : 752
# mean_time : 71.375
# times : (84, 61, 55, 63, 74, 62, 106, 66)
# ==========
#
# episode : 753
# mean_time : 72.5
# times : (85, 65, 54, 52, 99, 75, 94, 56)
# ==========
#
# episode : 754
# mean_time : 64.875
# times : (48, 76, 56, 90, 54, 88, 47, 60)
# ==========
#
# episode : 755
# mean_time : 63.625
# times : (55, 56, 60, 89, 52, 50, 94, 53)
# ==========
#
# episode : 756
# mean_time : 64.125
# times : (92, 65, 62, 58, 50, 77, 56, 53)
# ==========
#
# episode : 757
# mean_time : 61.75
# times : (57, 60, 66, 52, 69, 66, 62, 62)
# ==========
#
# episode : 758
# mean_time : 69.375
# times : (84, 78, 60, 97, 62, 51, 54, 69)
# ==========
#
# episode : 759
# mean_time : 67.625
# times : (49, 87, 76, 52, 73, 100, 46, 58)
# ==========
#
# episode : 760
# mean_time : 65.625
# times : (88, 54, 54, 64, 70, 50, 75, 70)
# ==========
#
# episode : 761
# mean_time : 67.75
# times : (48, 94, 65, 86, 54, 77, 56, 62)
# ==========
#
# episode : 762
# mean_time : 65.625
# times : (74, 63, 64, 63, 99, 63, 47, 52)
# ==========
#
# episode : 763
# mean_time : 66.75
# times : (74, 53, 59, 56, 78, 53, 97, 64)
# ==========
#
# episode : 764
# mean_time : 64.875
# times : (68, 77, 66, 88, 50, 64, 55, 51)
# ==========
#
# episode : 765
# mean_time : 60.375
# times : (85, 52, 70, 60, 59, 48, 54, 55)
# ==========
#
# episode : 766
# mean_time : 60.75
# times : (50, 66, 59, 61, 52, 92, 54, 52)
# ==========
#
# episode : 767
# mean_time : 68.5
# times : (63, 77, 69, 60, 51, 67, 102, 59)
# ==========
#
# episode : 768
# mean_time : 59.5
# times : (59, 61, 68, 66, 49, 52, 61, 60)
# ==========
#
# episode : 769
# mean_time : 74.625
# times : (48, 95, 98, 58, 61, 92, 69, 76)
# ==========
#
# episode : 770
# mean_time : 60.5
# times : (54, 53, 55, 66, 56, 68, 54, 78)
# ==========
#
# episode : 771
# mean_time : 61.75
# times : (90, 62, 56, 65, 51, 62, 55, 53)
# ==========
#
# episode : 772
# mean_time : 66.375
# times : (60, 57, 86, 55, 67, 67, 79, 60)
# ==========
#
# episode : 773
# mean_time : 77.125
# times : (72, 99, 73, 82, 62, 76, 92, 61)
# ==========
#
# episode : 774
# mean_time : 74.375
# times : (56, 92, 66, 50, 89, 58, 96, 88)
# ==========
#
# episode : 775
# mean_time : 65.25
# times : (61, 59, 76, 46, 61, 63, 100, 56)
# ==========
#
# episode : 776
# mean_time : 72.375
# times : (105, 56, 97, 59, 64, 52, 51, 95)
# ==========
#
# episode : 777
# mean_time : 69.75
# times : (68, 92, 52, 61, 50, 109, 63, 63)
# ==========
#
# episode : 778
# mean_time : 67.25
# times : (48, 66, 94, 65, 82, 68, 62, 53)
# ==========
#
# episode : 779
# mean_time : 69.5
# times : (102, 50, 55, 95, 76, 66, 55, 57)
# ==========
#
# episode : 780
# mean_time : 63.625
# times : (91, 68, 67, 52, 61, 56, 59, 55)
# ==========
#
# episode : 781
# mean_time : 69.5
# times : (56, 71, 77, 62, 76, 62, 59, 93)
# ==========
#
# episode : 782
# mean_time : 76.625
# times : (64, 69, 59, 122, 110, 52, 79, 58)
# ==========
#
# episode : 783
# mean_time : 98.375
# times : (71, 70, 200, 63, 68, 99, 107, 109)
# ==========
#
# episode : 784
# mean_time : 73.5
# times : (65, 73, 109, 70, 75, 57, 65, 74)
# ==========
#
# episode : 785
# mean_time : 69.75
# times : (64, 67, 76, 69, 86, 71, 56, 69)
# ==========
#
# episode : 786
# mean_time : 136.0
# times : (200, 74, 90, 78, 200, 200, 149, 97)
# ==========
#
# episode : 787
# mean_time : 102.25
# times : (83, 123, 72, 200, 95, 92, 80, 73)
# ==========
#
# episode : 788
# mean_time : 160.125
# times : (200, 200, 83, 200, 98, 200, 200, 100)
# ==========
#
# episode : 789
# mean_time : 103.25
# times : (72, 70, 112, 151, 98, 93, 146, 84)
# ==========
#
# episode : 790
# mean_time : 118.25
# times : (130, 82, 105, 90, 200, 76, 140, 123)
# ==========
#
# episode : 791
# mean_time : 140.5
# times : (109, 200, 88, 200, 121, 90, 200, 116)
# ==========
#
# episode : 792
# mean_time : 135.0
# times : (121, 200, 86, 156, 168, 109, 93, 147)
# ==========
#
# episode : 793
# mean_time : 146.0
# times : (125, 109, 200, 115, 200, 83, 136, 200)
# ==========
#
# episode : 794
# mean_time : 140.0
# times : (109, 130, 123, 200, 118, 114, 126, 200)
# ==========
#
# episode : 795
# mean_time : 175.25
# times : (100, 129, 173, 200, 200, 200, 200, 200)
# ==========
#
# episode : 796
# mean_time : 171.875
# times : (137, 200, 152, 86, 200, 200, 200, 200)
# ==========
#
# episode : 797
# mean_time : 183.125
# times : (200, 200, 200, 200, 200, 141, 163, 161)
# ==========
#
# episode : 798
# mean_time : 166.375
# times : (95, 200, 200, 156, 82, 200, 198, 200)
# ==========
#
# episode : 799
# mean_time : 147.5
# times : (200, 196, 167, 192, 73, 200, 74, 78)
# ==========
