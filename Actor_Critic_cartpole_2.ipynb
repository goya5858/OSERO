# %% [markdown]
# <a href="https://colab.research.google.com/github/goya5858/OSERO/blob/main/Actor_Critic_cartpole_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import torch.multiprocessing as mp
import time

import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gym
import numpy as np
import matplotlib.pyplot as plt
from torch.nn import functional as F

# %% [markdown]
# # Agent

# %%
class Agent_Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1  = nn.Linear(4, 32)
        self.act1 = nn.ReLU()

        self.fc2  = nn.Linear(32, 32)
        self.act2 = nn.ReLU()

        self.pi_net = nn.Linear(32, 2)
        self.pi_act = nn.Softmax()

        self.V_net = nn.Linear(32,1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act1(x)

        x = self.fc2(x)
        x = self.act2(x)

        pi = self.pi_net(x)
        pi = self.pi_act(pi)

        V = self.V_net(x)
        return pi, V

# %%
import torch
import numpy as np
from torch.distributions import Categorical

a = torch.tensor([0.3, 0.7] )
m = Categorical(a)

S = []
for i in range(1000):
    S.append( m.sample() )


m.log_prob(m.sample())
# Out:
# tensor(-1.2040)

# %%
from collections import namedtuple
Transition = namedtuple('Transition', ('state', 'action', 'reward', 'log_prob', 'v_value') )

class Agent_Memory():
    def __init__(self):
        self.capacity = CAPACITY #メモリの大きさ
        self.memory = []
        self.index = 0

    def sample(self):
        transitions = self.memory
        BATCH = Transition(*zip(*transitions)) #State, Action, Reward, State_Nextの各要素ごとにまとめ直す

        State_BATCH      = torch.tensor( np.stack( BATCH.state ) ,dtype=torch.float)
        Action_BATCH     = torch.tensor( np.stack( BATCH.action ) ,dtype=torch.int64)
        Reward_BATCH     = torch.tensor( np.stack( BATCH.reward ) ,dtype=torch.float)
        Log_prob_BATCH   = torch.stack( BATCH.log_prob )
        V_value_BATCH    = torch.stack( BATCH.v_value )
        return State_BATCH, Action_BATCH, Reward_BATCH, Log_prob_BATCH, V_value_BATCH

    def put_memory(self, state, action, reward, log_prob, v_value):
        '''transition = (state, action, reward, state_next)をメモリに保存する'''
        if len(self.memory) < self.capacity:
            self.memory.append(None)  # メモリが満タンでないときは足す
        self.memory[self.index] = Transition(state, action, reward, log_prob, v_value)
        self.index = (self.index + 1) % self.capacity  # 保存するindexを1つずらす

# %%
class Agent():
    def __init__(self):
        self.Network = Agent_Network()
        self.Memory  = Agent_Memory()
        self.optim   = optim.Adam(self.Network.parameters(), lr=0.005)

    def get_action(self, state, episode): 
        # ε-greedy法で徐々に最適行動のみを採用する
        #self.Network.eval()  # ネットワークを推論モードに切り替える
        pi_values, V_value = self.Network( torch.tensor( state, dtype=torch.float ) )
        m = Categorical(pi_values)

        epsilon = 0.5 * (1 / (episode + 1))
        if epsilon <= np.random.uniform(0, 1):
            action = m.sample()
        else:
            action = np.random.choice(2)   # 0,1の行動をランダムに返す
            action = torch.tensor( action )
        #log_prob = -1 * m.log_prob(action)
        pi_prob = m.probs[ action.to(torch.long) ]
        return action, pi_prob, V_value[0]

    def update_Network(self):
        # Memoryから学習用のデータを取り出す
        State_BATCH, Action_BATCH, Reward_BATCH, Pi_prob_BATCH, V_value_BATCH = self.Memory.sample()
        
        R = 0
        for i in reversed( range(len(Reward_BATCH)) ):
            r = Reward_BATCH[i]
            R = r + GAMMA * R
            Reward_BATCH[i] = R
        
        Advantage = Reward_BATCH - V_value_BATCH
        V_loss  = Advantage.pow(2).mean() #２乗平均をとる
        Log_prob_BATCH = -1 * torch.log( Pi_prob_BATCH )
        pi_gain = ( Log_prob_BATCH * Advantage.detach() ).mean()
        entropy  = -1 * ( Pi_prob_BATCH * Log_prob_BATCH ).mean()

        loss = V_loss + pi_gain + entropy*0.1
        
        self.optim.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.Network.parameters(), 0.01)
        self.optim.step() 

        self.Memory.memory = []
        self.Memory.index = 0
    
    def memorize(self, state, action, reward, log_prob, v_value):
        self.Memory.put_memory(state, action, reward, log_prob, v_value)

# %% [markdown]
# # Task

# %%
Task_model = gym.make('CartPole-v0')

# %% [markdown]
# # Training Environment

# %%
class Environment():
    def __init__(self):
        self.Task  = Task_model
        self.Agent = Agent()
    
    def run_one_episode(self, episode):
        # 倒れるか、200秒持ち堪え耐えるまでが１エピソード        
        t = 0
        state = self.Task.reset() # 各episodeの最初にTaskをリセット
        reword = 0

        while True:
            action, pi_prob, v_value  = self.Agent.get_action(state, episode)
            state_next, reword, done, info = self.Task.step(action.item()) #Action_tを場面に渡してState_t+1, Reword_tを受け取る
            
            if done: #倒れていたor終了した場合
                next_state = None
                if t < 195: #195ステップいないなら失敗
                    reword = -1
                else: #195ステップ以上たってたら成功
                    reword = 1
            else: #各ステップで立ってたら報酬追加
                reword = 0
            
            # 結果の記録とモデルの更新
            self.Agent.memorize(state, action, reword, pi_prob, v_value)
            

            state = state_next
            t += 1

            if done:
                break
        self.Agent.update_Network() #エピソードの終わりに更新
        return t
    
    def train(self):
        TIMES = []
        times = 0
        episode = 0
        while True:
            times = self.run_one_episode(episode)
            print('episode :', episode)
            print(times)
            print('='*10)
            episode += 1
            TIMES.append(times)

            if ( (len(TIMES) > 10) & (np.mean(TIMES[-10:]) >= 200) ) or (len(TIMES) > MAX_ITER):
                break
        return TIMES

# %%
GAMMA = 0.99
CAPACITY = 10000
#BATCH_SIZE = 32
MAX_ITER = 1000

AAA = Environment()
TTT = AAA.train()

X = range(len(TTT))
plt.plot(X, TTT)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# episode : 0
# 15
# ==========
# episode : 1
# 30
# ==========
# episode : 2
# 55
# ==========
# episode : 3
# 10
# ==========
# episode : 4
# 19
# ==========
# episode : 5
# 27
# ==========
# episode : 6
# 18
# ==========
# episode : 7
# 16
# ==========
# episode : 8
# 27
# ==========
# episode : 9
# 17
# ==========
# episode : 10
# 16
# ==========
# episode : 11
# 15
# ==========
# episode : 12
# 11
# ==========
# episode : 13
# 15
# ==========
# episode : 14
# 14
# ==========
# episode : 15
# 39
# ==========
# episode : 16
# 51
# ==========
# episode : 17
# 14
# ==========
# episode : 18
# 11
# ==========
# episode : 19
# 13
# ==========
# episode : 20
# 11
# ==========
# episode : 21
# 12
# ==========
# episode : 22
# 13
# ==========
# episode : 23
# 17
# ==========
# episode : 24
# 14
# ==========
# episode : 25
# 17
# ==========
# episode : 26
# 27
# ==========
# episode : 27
# 17
# ==========
# episode : 28
# 15
# ==========
# episode : 29
# 14
# ==========
# episode : 30
# 81
# ==========
# episode : 31
# 19
# ==========
# episode : 32
# 15
# ==========
# episode : 33
# 32
# ==========
# episode : 34
# 24
# ==========
# episode : 35
# 15
# ==========
# episode : 36
# 44
# ==========
# episode : 37
# 11
# ==========
# episode : 38
# 37
# ==========
# episode : 39
# 12
# ==========
# episode : 40
# 26
# ==========
# episode : 41
# 19
# ==========
# episode : 42
# 15
# ==========
# episode : 43
# 44
# ==========
# episode : 44
# 19
# ==========
# episode : 45
# 15
# ==========
# episode : 46
# 22
# ==========
# episode : 47
# 22
# ==========
# episode : 48
# 31
# ==========
# episode : 49
# 13
# ==========
# episode : 50
# 14
# ==========
# episode : 51
# 45
# ==========
# episode : 52
# 55
# ==========
# episode : 53
# 21
# ==========
# episode : 54
# 20
# ==========
# episode : 55
# 38
# ==========
# episode : 56
# 61
# ==========
# episode : 57
# 15
# ==========
# episode : 58
# 23
# ==========
# episode : 59
# 19
# ==========
# episode : 60
# 31
# ==========
# episode : 61
# 18
# ==========
# episode : 62
# 14
# ==========
# episode : 63
# 36
# ==========
# episode : 64
# 51
# ==========
# episode : 65
# 21
# ==========
# episode : 66
# 35
# ==========
# episode : 67
# 29
# ==========
# episode : 68
# 38
# ==========
# episode : 69
# 38
# ==========
# episode : 70
# 15
# ==========
# episode : 71
# 18
# ==========
# episode : 72
# 23
# ==========
# episode : 73
# 12
# ==========
# episode : 74
# 9
# ==========
# episode : 75
# 36
# ==========
# episode : 76
# 16
# ==========
# episode : 77
# 28
# ==========
# episode : 78
# 17
# ==========
# episode : 79
# 31
# ==========
# episode : 80
# 12
# ==========
# episode : 81
# 14
# ==========
# episode : 82
# 89
# ==========
# episode : 83
# 28
# ==========
# episode : 84
# 13
# ==========
# episode : 85
# 18
# ==========
# episode : 86
# 28
# ==========
# episode : 87
# 17
# ==========
# episode : 88
# 12
# ==========
# episode : 89
# 14
# ==========
# episode : 90
# 27
# ==========
# episode : 91
# 30
# ==========
# episode : 92
# 20
# ==========
# episode : 93
# 19
# ==========
# episode : 94
# 11
# ==========
# episode : 95
# 78
# ==========
# episode : 96
# 38
# ==========
# episode : 97
# 9
# ==========
# episode : 98
# 23
# ==========
# episode : 99
# 32
# ==========
# episode : 100
# 43
# ==========
# episode : 101
# 24
# ==========
# episode : 102
# 19
# ==========
# 17
# ==========
# episode : 476
# 21
# ==========
# episode : 477
# 43
# ==========
# episode : 478
# 33
# ==========
# episode : 479
# 37
# ==========
# episode : 480
# 44
# ==========
# episode : 481
# 58
# ==========
# episode : 482
# 64
# ==========
# episode : 483
# 34
# ==========
# episode : 484
# 48
# ==========
# episode : 485
# 36
# ==========
# episode : 486
# 24
# ==========
# episode : 487
# 43
# ==========
# episode : 488
# 52
# ==========
# episode : 489
# 35
# ==========
# episode : 490
# 38
# ==========
# episode : 491
# 86
# ==========
# episode : 492
# 18
# ==========
# episode : 493
# 61
# ==========
# episode : 494
# 65
# ==========
# episode : 495
# 32
# ==========
# episode : 496
# 32
# ==========
# episode : 497
# 75
# ==========
# episode : 498
# 87
# ==========
# episode : 499
# 35
# ==========
# episode : 500
# 53
# ==========
# episode : 501
# 27
# ==========
# episode : 502
# 43
# ==========
# episode : 503
# 33
# ==========
# episode : 504
# 73
# ==========
# episode : 505
# 38
# ==========
# episode : 506
# 15
# ==========
# episode : 507
# 77
# ==========
# episode : 508
# 101
# ==========
# episode : 509
# 35
# ==========
# episode : 510
# 32
# ==========
# episode : 511
# 46
# ==========
# episode : 512
# 12
# ==========
# episode : 513
# 33
# ==========
# episode : 514
# 39
# ==========
# episode : 515
# 32
# ==========
# episode : 516
# 29
# ==========
# episode : 517
# 40
# ==========
# episode : 518
# 24
# ==========
# episode : 519
# 38
# ==========
# episode : 520
# 28
# ==========
# episode : 521
# 18
# ==========
# episode : 522
# 40
# ==========
# episode : 523
# 60
# ==========
# episode : 524
# 46
# ==========
# episode : 525
# 17
# ==========
# episode : 526
# 15
# ==========
# episode : 527
# 73
# ==========
# episode : 528
# 13
# ==========
# episode : 529
# 109
# ==========
# episode : 530
# 43
# ==========
# episode : 531
# 109
# ==========
# episode : 532
# 122
# ==========
# episode : 533
# 151
# ==========
# episode : 534
# 80
# ==========
# episode : 535
# 17
# ==========
# episode : 536
# 169
# ==========
# episode : 537
# 16
# ==========
# episode : 538
# 19
# ==========
# episode : 539
# 50
# ==========
# episode : 540
# 45
# ==========
# episode : 541
# 13
# ==========
# episode : 542
# 32
# ==========
# episode : 543
# 172
# ==========
# episode : 544
# 71
# ==========
# episode : 545
# 101
# ==========
# episode : 546
# 60
# ==========
# episode : 547
# 32
# ==========
# episode : 548
# 19
# ==========
# episode : 549
# 101
# ==========
# episode : 550
# 12
# ==========
# episode : 551
# 69
# ==========
# episode : 552
# 61
# ==========
# episode : 553
# 12
# ==========
# episode : 554
# 78
# ==========
# episode : 555
# 41
# ==========
# episode : 556
# 25
# ==========
# episode : 557
# 45
# ==========
# episode : 558
# 63
# ==========
# episode : 559
# 23
# ==========
# episode : 560
# 40
# ==========
# episode : 561
# 25
# ==========
# episode : 562
# 78
# ==========
# episode : 563
# 65
# ==========
# episode : 564
# 79
# ==========
# episode : 565
# 52
# ==========
# episode : 566
# 52
# ==========
# episode : 567
# 21
# ==========
# episode : 568
# 48
# ==========
# episode : 569
# 108
# ==========
# episode : 570
# 68
# ==========
# episode : 571
# 72
# ==========
# episode : 572
# 145
# ==========
# episode : 573
# 11
# ==========
# episode : 574
# 76
# ==========
# episode : 575
# 144
# ==========
# episode : 576
# 39
# ==========
# episode : 577
# 13
# ==========
# episode : 578
# 134
# ==========
# episode : 579
# 62
# ==========
# episode : 580
# 73
# ==========
# episode : 581
# 12
# ==========
# episode : 582
# 41
# ==========
# episode : 583
# 69
# ==========
# episode : 584
# 25
# ==========
# episode : 585
# 11
# ==========
# episode : 586
# 19
# ==========
# episode : 587
# 52
# ==========
# episode : 588
# 22
# ==========
# episode : 589
# 54
# ==========
# episode : 590
# 32
# ==========
# episode : 591
# 99
# ==========
# episode : 592
# 114
# ==========
# episode : 593
# 68
# ==========
# episode : 594
# 164
# ==========
# episode : 595
# 129
# ==========
# episode : 596
# 171
# ==========
# episode : 597
# 96
# ==========
# episode : 598
# 58
# ==========
# episode : 599
# 128
# ==========
# episode : 600
# 109
# ==========
# episode : 601
# 54
# ==========
# episode : 602
# 114
# ==========
# episode : 603
# 66
# ==========
# episode : 604
# 25
# ==========
# episode : 605
# 130
# ==========
# episode : 606
# 65
# ==========
# episode : 607
# 61
# ==========
# episode : 608
# 47
# ==========
# episode : 609
# 54
# ==========
# episode : 610
# 90
# ==========
# episode : 611
# 200
# ==========
# episode : 612
# 83
# ==========
# episode : 613
# 108
# ==========
# episode : 614
# 63
# ==========
# episode : 615
# 102
# ==========
# episode : 616
# 19
# ==========
# episode : 617
# 44
# ==========
# episode : 618
# 91
# ==========
# episode : 619
# 34
# ==========
# episode : 620
# 30
# ==========
# episode : 621
# 40
# ==========
# episode : 622
# 85
# ==========
# episode : 623
# 87
# ==========
# episode : 624
# 123
# ==========
# episode : 625
# 110
# ==========
# episode : 626
# 61
# ==========
# episode : 627
# 70
# ==========
# episode : 628
# 141
# ==========
# episode : 629
# 28
# ==========
# episode : 630
# 31
# ==========
# episode : 631
# 77
# ==========
# episode : 632
# 103
# ==========
# episode : 633
# 11
# ==========
# episode : 634
# 131
# ==========
# episode : 635
# 34
# ==========
# episode : 636
# 77
# ==========
# episode : 637
# 127
# ==========
# episode : 638
# 25
# ==========
# episode : 639
# 40
# ==========
# episode : 640
# 77
# ==========
# episode : 641
# 88
# ==========
# episode : 642
# 125
# ==========
# episode : 643
# 29
# ==========
# episode : 644
# 40
# ==========
# episode : 645
# 58
# ==========
# episode : 646
# 32
# ==========
# episode : 647
# 106
# ==========
# episode : 648
# 40
# ==========
# episode : 649
# 18
# ==========
# episode : 650
# 55
# ==========
# episode : 651
# 89
# ==========
# episode : 652
# 18
# ==========
# episode : 653
# 22
# ==========
# episode : 654
# 19
# ==========
# episode : 655
# 64
# ==========
# episode : 656
# 200
# ==========
# episode : 657
# 24
# ==========
# episode : 658
# 33
# ==========
# episode : 659
# 62
# ==========
# episode : 660
# 48
# ==========
# episode : 661
# 114
# ==========
# episode : 662
# 138
# ==========
# episode : 663
# 155
# ==========
# episode : 664
# 39
# ==========
# episode : 665
# 75
# ==========
# episode : 666
# 32
# ==========
# episode : 667
# 154
# ==========
# episode : 668
# 44
# ==========
# episode : 669
# 86
# ==========
# episode : 670
# 87
# ==========
# episode : 671
# 25
# ==========
# episode : 672
# 21
# ==========
# episode : 673
# 59
# ==========
# episode : 674
# 97
# ==========
# episode : 675
# 168
# ==========
# episode : 676
# 75
# ==========
# episode : 677
# 21
# ==========
# episode : 678
# 128
# ==========
# episode : 679
# 106
# ==========
# episode : 680
# 146
# ==========
# episode : 681
# 113
# ==========
# episode : 682
# 95
# ==========
# episode : 683
# 126
# ==========
# episode : 684
# 75
# ==========
# episode : 685
# 188
# ==========
# episode : 686
# 72
# ==========
# episode : 687
# 56
# ==========
# episode : 688
# 89
# ==========
# episode : 689
# 69
# ==========
# episode : 690
# 18
# ==========
# episode : 691
# 22
# ==========
# episode : 692
# 94
# ==========
# episode : 693
# 58
# ==========
# episode : 694
# 83
# ==========
# episode : 695
# 80
# ==========
# episode : 696
# 200
# ==========
# episode : 697
# 187
# ==========
# episode : 698
# 17
# ==========
# episode : 699
# 158
# ==========
# episode : 700
# 44
# ==========
# episode : 701
# 180
# ==========
# episode : 702
# 200
# ==========
# episode : 703
# 57
# ==========
# episode : 704
# 66
# ==========
# episode : 705
# 102
# ==========
# episode : 706
# 130
# ==========
# episode : 707
# 17
# ==========
# episode : 708
# 78
# ==========
# episode : 709
# 45
# ==========
# episode : 710
# 121
# ==========
# episode : 711
# 119
# ==========
# episode : 712
# 200
# ==========
# episode : 713
# 24
# ==========
# episode : 714
# 82
# ==========
# episode : 715
# 153
# ==========
# episode : 716
# 154
# ==========
# episode : 717
# 53
# ==========
# episode : 718
# 91
# ==========
# episode : 719
# 78
# ==========
# episode : 720
# 200
# ==========
# episode : 721
# 200
# ==========
# episode : 722
# 129
# ==========
# episode : 723
# 200
# ==========
# episode : 724
# 94
# ==========
# episode : 725
# 118
# ==========
# episode : 726
# 90
# ==========
# episode : 727
# 200
# ==========
# episode : 728
# 200
# ==========
# episode : 729
# 54
# ==========
# episode : 730
# 196
# ==========
# episode : 731
# 87
# ==========
# episode : 732
# 200
# ==========
# episode : 733
# 181
# ==========
# episode : 734
# 178
# ==========
# episode : 735
# 200
# ==========
# episode : 736
# 52
# ==========
# episode : 737
# 138
# ==========
# episode : 738
# 73
# ==========
# episode : 739
# 200
# ==========
# episode : 740
# 200
# ==========
# episode : 741
# 200
# ==========
# episode : 742
# 120
# ==========
# episode : 743
# 186
# ==========
# episode : 744
# 174
# ==========
# episode : 745
# 200
# ==========
# episode : 746
# 200
# ==========
# episode : 747
# 200
# ==========
# episode : 748
# 200
# ==========
# episode : 749
# 200
# ==========
# episode : 750
# 200
# ==========
# episode : 751
# 200
# ==========
# episode : 752
# 200
# ==========
# episode : 753
# 200
# ==========
# episode : 754
# 200
# ==========
